# %% [markdown]
# # Game Recommender for Games on Steam
#
# ## Project Description
#
# In this project we are going to create three different recommenders for games* on Steam.
# 1. Knowledge-based recommender (a filter).
# 2. Content-based recommender, based on app description.
# 3. Content-based recommender, based on tags and developers (app metadata).
#
# We'll also use Streamlit to create the application for this recommenders.
#
#
# **datasets also contain information about soundtracks, software and films, but the main focus of this recommenders is games.*

# %% [markdown]
# ## Set Up
# ### Downloading Files
# #### ***! VERY IMPORTANT***
# ***Please consider running code in the next code cell - this files are crucial for running recommender applications***.
#
# You don't need to wait till the end of code execution and can proceed further in observing the notebook.

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1UlXewxo8rSvL-hAqF8TM0BYnlB_judDW' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1UlXewxo8rSvL-hAqF8TM0BYnlB_judDW" -O recommender_files.zip && rm -rf /tmp/cookies.txt
# !unzip recommender_files.zip &> /dev/null
# !rm -rf __MACOSX & rm -rf recommender_files.zip

# %% [markdown]
# ### Importing Libraries and Updating Settings

# %%
import os
import json
import numpy as np
import pandas as pd


pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option("display.precision", 4)

# %% [markdown]
# ## Getting the Data
# ### About the Data

# %% [markdown]
# We'll use data from two different sources:
#
# 1. Two datasets from [Game Recommendations on Steam Dataset](https://www.kaggle.com/datasets/antonkozyriev/game-recommendations-on-steam/data?select=games.csv):
#     - **games.csv** as the main source of information.
#         - Contains information about game *title*, *release date*, *rating*, *price* and *compatibility with different platforms*.
#     - **games_metadata.json** for dame metadata.
#         - Contains information about game *tags* and *descriptions*.
# 2. One dataset from [Steam Games Dataset](https://www.kaggle.com/datasets/fronkongames/steam-games-dataset/data?select=games.json):
#     - **games.json** for some additional information about games (*image*, *developers*).

# %% [markdown]
# ### Loading Data into Data Frames

# %% [markdown]
# Dataset with main data.

# %%
data = pd.read_csv("recommender_files/data/games.csv", index_col = "app_id")

data.head()
# Out:
#                      title                date_release   win   mac   linux  \
# app_id
# 13500   Prince of Persia: Warrior Within™  2008-11-21   True  False  False
# 22364             BRINK: Agents of Change  2011-08-03   True  False  False
# 113020       Monaco: What's Yours Is Mine  2013-04-24   True   True   True
# 226560                 Escape Dead Island  2014-11-18   True  False  False
# 249050            Dungeon of the ENDLESS™  2014-10-27   True   True  False
#
#            rating      positive_ratio  user_reviews  price_final  \
# app_id
# 13500   Very Positive        84            2199          9.99
# 22364        Positive        85              21          2.99
# 113020  Very Positive        92            3722         14.99
# 226560          Mixed        61             873         14.99
# 249050  Very Positive        88            8784         11.99
#
#         price_original  discount  steam_deck
# app_id
# 13500         9.99         0.0       True
# 22364         2.99         0.0       True
# 113020       14.99         0.0       True
# 226560       14.99         0.0       True
# 249050       11.99         0.0       True

# %% [markdown]
# Dataset with metadata.

# %%
# this file is not in a "valid json" format so we need to read it line by line
metadata = [json.loads(line)
        for line in open('recommender_files/data/games_metadata.json', 'r', encoding='utf-8')]

# %%
meta = pd.DataFrame(metadata)
meta = meta.set_index("app_id")

meta.head()
# Out:
#                           description                      \
# app_id
# 13500   Enter the dark underworld of Prince of Persia ...
# 22364
# 113020  Monaco: What's Yours Is Mine is a single playe...
# 226560  Escape Dead Island is a Survival-Mystery adven...
# 249050  Dungeon of the Endless is a Rogue-Like Dungeon...
#
#                               tags
# app_id
# 13500   [Action, Adventure, Parkour, Third Person, Gre...
# 22364                                            [Action]
# 113020  [Co-op, Stealth, Indie, Heist, Local Co-Op, St...
# 226560  [Zombies, Adventure, Survival, Action, Third P...
# 249050  [Roguelike, Strategy, Tower Defense, Pixel Gra...

# %% [markdown]
# Dataset with additional data.

# %%
add_set = {}
with open('recommender_files/data/games.json', 'r', encoding='utf-8') as fin:
  text = fin.read()
  add_set = json.loads(text)

# %%
additions = pd.DataFrame(add_set).T
additions.index = additions.index.astype(np.int64)

additions.head()
# Out:
#                  name           release_date required_age price  dlc_count  \
# 20200         Galactic Bowling  Oct 21, 2008       0       19.99      0
# 655370            Train Bandit  Oct 12, 2017       0        0.99      0
# 1732930           Jolt Project  Nov 17, 2021       0        4.99      0
# 1355720               Henosis™  Jul 23, 2020       0        5.99      0
# 1139950  Two Weeks in Painland   Feb 3, 2020       0         0.0      0
#
#                        detailed_description                 \
# 20200    Galactic Bowling is an exaggerated and stylize...
# 655370   THE LAW!! Looks to be a showdown atop a train....
# 1732930  Jolt Project: The army now has a new robotics ...
# 1355720  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# 1139950  ABOUT THE GAME Play as a hacker who has arrang...
#
#                           about_the_game                    \
# 20200    Galactic Bowling is an exaggerated and stylize...
# 655370   THE LAW!! Looks to be a showdown atop a train....
# 1732930  Jolt Project: The army now has a new robotics ...
# 1355720  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# 1139950  ABOUT THE GAME Play as a hacker who has arrang...
#
#                         short_description                  reviews  \
# 20200    Galactic Bowling is an exaggerated and stylize...
# 655370   THE LAW!! Looks to be a showdown atop a train....
# 1732930  Shoot vehicles, blow enemies with a special at...
# 1355720  HENOSIS™ is a mysterious 2D Platform Puzzler w...
# 1139950  Two Weeks in Painland is a story-driven game a...
#
#                            header_image                     \
# 20200    https://cdn.akamai.steamstatic.com/steam/apps/...
# 655370   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1732930  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1355720  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1139950  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                       website                 \
# 20200         http://www.galacticbowling.net
# 655370                http://trainbandit.com
# 1732930
# 1355720             https://henosisgame.com/
# 1139950  https://www.unusual-games.com/home/
#
#                       support_url                \
# 20200
# 655370
# 1732930
# 1355720                https://henosisgame.com/
# 1139950  https://www.unusual-games.com/contact/
#
#                  support_email           windows  mac   linux   \
# 20200                                      True   False  False
# 655370           support@rustymoyher.com   True    True  False
# 1732930        ramoncampiaof31@gmail.com   True   False  False
# 1355720             info@henosisgame.com   True    True   True
# 1139950  welistentoyou@unusual-games.com   True    True  False
#
#         metacritic_score metacritic_url achievements recommendations  \
# 20200           0                            30              0
# 655370          0                            12              0
# 1732930         0                             0              0
# 1355720         0                             0              0
# 1139950         0                            17              0
#
#                               notes                         \
# 20200
# 655370
# 1732930
# 1355720
# 1139950  This Game may contain content not appropriate ...
#
#                        supported_languages                  \
# 20200                                            [English]
# 655370   [English, French, Italian, German, Spanish - S...
# 1732930                     [English, Portuguese - Brazil]
# 1355720  [English, French, Italian, German, Spanish - S...
# 1139950                         [English, Spanish - Spain]
#
#         full_audio_languages  \
# 20200            []
# 655370           []
# 1732930          []
# 1355720          []
# 1139950          []
#
#                              packages                       \
# 20200    [{'title': 'Buy Galactic Bowling', 'descriptio...
# 655370   [{'title': 'Buy Train Bandit', 'description': ...
# 1732930  [{'title': 'Buy Jolt Project', 'description': ...
# 1355720  [{'title': 'Buy Henosis™', 'description': '', ...
# 1139950                                                 []
#
#                developers               publishers         \
# 20200    [Perpetual FX Creative]  [Perpetual FX Creative]
# 655370            [Rusty Moyher]           [Wild Rooster]
# 1732930          [Campião Games]          [Campião Games]
# 1355720      [Odd Critter Games]      [Odd Critter Games]
# 1139950          [Unusual Games]          [Unusual Games]
#
#                             categories                      \
# 20200    [Single-player, Multi-player, Steam Achievemen...
# 655370   [Single-player, Steam Achievements, Full contr...
# 1732930                                    [Single-player]
# 1355720           [Single-player, Full controller support]
# 1139950                [Single-player, Steam Achievements]
#
#                         genres                 \
# 20200                 [Casual, Indie, Sports]
# 655370                        [Action, Indie]
# 1732930  [Action, Adventure, Indie, Strategy]
# 1355720            [Adventure, Casual, Indie]
# 1139950                    [Adventure, Indie]
#
#                            screenshots                      \
# 20200    [https://cdn.akamai.steamstatic.com/steam/apps...
# 655370   [https://cdn.akamai.steamstatic.com/steam/apps...
# 1732930  [https://cdn.akamai.steamstatic.com/steam/apps...
# 1355720  [https://cdn.akamai.steamstatic.com/steam/apps...
# 1139950  [https://cdn.akamai.steamstatic.com/steam/apps...
#
#                               movies                       user_score  \
# 20200    [http://cdn.akamai.steamstatic.com/steam/apps/...      0
# 655370   [http://cdn.akamai.steamstatic.com/steam/apps/...      0
# 1732930  [http://cdn.akamai.steamstatic.com/steam/apps/...      0
# 1355720  [http://cdn.akamai.steamstatic.com/steam/apps/...      0
# 1139950  [http://cdn.akamai.steamstatic.com/steam/apps/...      0
#
#         score_rank positive negative estimated_owners  \
# 20200                  6       11        0 - 20000
# 655370                53        5        0 - 20000
# 1732930                0        0        0 - 20000
# 1355720                3        0        0 - 20000
# 1139950               50        8        0 - 20000
#
#         average_playtime_forever average_playtime_2weeks  \
# 20200               0                        0
# 655370              0                        0
# 1732930             0                        0
# 1355720             0                        0
# 1139950             0                        0
#
#         median_playtime_forever median_playtime_2weeks peak_ccu  \
# 20200               0                      0               0
# 655370              0                      0               0
# 1732930             0                      0               0
# 1355720             0                      0               0
# 1139950             0                      0               0
#
#                                tags
# 20200    {'Indie': 22, 'Casual': 21, 'Sports': 21, 'Bow...
# 655370   {'Indie': 109, 'Action': 103, 'Pixel Graphics'...
# 1732930                                                 []
# 1355720  {'2D Platformer': 161, 'Atmospheric': 154, 'Su...
# 1139950  {'Indie': 42, 'Adventure': 41, 'Nudity': 22, '...

# %% [markdown]
# Fetching `images` column beforehand to join with our main dataset later.

# %%
images = additions[["header_image"]].copy()

images.head()
# Out:
#                            header_image
# 20200    https://cdn.akamai.steamstatic.com/steam/apps/...
# 655370   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1732930  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1355720  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1139950  https://cdn.akamai.steamstatic.com/steam/apps/...

# %% [markdown]
# ### Cleaning and Preparing the Data

# %% [markdown]
# Joining main dataset with metadata.

# %%
df = data.join(meta)

# %% [markdown]
# Cleaning rows with no information about tags.

# %%
empty_tags_ids = list()
for index, value in zip(df["tags"].index, df["tags"]):
    if value == list():
        empty_tags_ids.append(index)

# %%
df = df.drop(index = empty_tags_ids)

# %% [markdown]
# Dropping columns without description.

# %%
empty_description_ids = df.loc[df["description"] == ""].index

df = df.drop(index = empty_description_ids)

# %% [markdown]
# Joining cleaned dataset with image urls.

# %%
df = df.join(images)

df.head()
# Out:
#                      title                date_release   win   mac   linux  \
# app_id
# 13500   Prince of Persia: Warrior Within™  2008-11-21   True  False  False
# 113020       Monaco: What's Yours Is Mine  2013-04-24   True   True   True
# 226560                 Escape Dead Island  2014-11-18   True  False  False
# 249050            Dungeon of the ENDLESS™  2014-10-27   True   True  False
# 250180                       METAL SLUG 3  2015-09-14   True  False  False
#
#            rating      positive_ratio  user_reviews  price_final  \
# app_id
# 13500   Very Positive        84            2199          9.99
# 113020  Very Positive        92            3722         14.99
# 226560          Mixed        61             873         14.99
# 249050  Very Positive        88            8784         11.99
# 250180  Very Positive        90            5579          7.99
#
#         price_original  discount  steam_deck  \
# app_id
# 13500         9.99         0.0       True
# 113020       14.99         0.0       True
# 226560       14.99         0.0       True
# 249050       11.99         0.0       True
# 250180        7.99         0.0       True
#
#                           description                      \
# app_id
# 13500   Enter the dark underworld of Prince of Persia ...
# 113020  Monaco: What's Yours Is Mine is a single playe...
# 226560  Escape Dead Island is a Survival-Mystery adven...
# 249050  Dungeon of the Endless is a Rogue-Like Dungeon...
# 250180  “METAL SLUG 3”, the masterpiece in SNK’s emble...
#
#                               tags                         \
# app_id
# 13500   [Action, Adventure, Parkour, Third Person, Gre...
# 113020  [Co-op, Stealth, Indie, Heist, Local Co-Op, St...
# 226560  [Zombies, Adventure, Survival, Action, Third P...
# 249050  [Roguelike, Strategy, Tower Defense, Pixel Gra...
# 250180  [Arcade, Classic, Action, Co-op, Side Scroller...
#
#                           header_image
# app_id
# 13500   https://cdn.akamai.steamstatic.com/steam/apps/...
# 113020  https://cdn.akamai.steamstatic.com/steam/apps/...
# 226560  https://cdn.akamai.steamstatic.com/steam/apps/...
# 249050  https://cdn.akamai.steamstatic.com/steam/apps/...
# 250180  https://cdn.akamai.steamstatic.com/steam/apps/...

# %% [markdown]
# Checking if there are any apps without image urls.

# %%
df.header_image.isna().sum()
# Out:
# 233

# %% [markdown]
# Filling in missing values.

# %%
no_image_ids = df.loc[df.header_image.isna()].index

for id in no_image_ids:
    df.loc[id, "header_image"] = f"https://cdn.akamai.steamstatic.com/steam/apps/{id}/header.jpg"

# %% [markdown]
# ### Saving Cleaned Datasets

# %% [markdown]
# Saving datasets for later use in applications.

# %%
#developers column is added for future metadata based recommender
df = df.join(additions["developers"])

df = df[['title', 'date_release',
         'description', "tags", "developers",
         'rating', 'positive_ratio', 'user_reviews',
         'win', 'mac', 'linux', 'steam_deck',
         'price_final','header_image']].copy()

df.to_parquet("recommender_files/data/gameset.parquet")

# %% [markdown]
# ## Building Knowledge-Based Recommender (Ranking by Genre)

# %% [markdown]
# In this first simple recommender the user will be asked to provide the genre. Recommender will filter the results for this genre and show top-25 best games based on review scores.

# %% [markdown]
# ### Encoding Tags

# %% [markdown]
# In order to make this recommender work, `tags` column must be reshaped.
#
# Each tag should be represented as a separate column with binary values, that show whether a game has this tag or not.

# %%
df["tags"].head()
# Out:
# app_id
# 13500     [Action, Adventure, Parkour, Third Person, Gre...
# 113020    [Co-op, Stealth, Indie, Heist, Local Co-Op, St...
# 226560    [Zombies, Adventure, Survival, Action, Third P...
# 249050    [Roguelike, Strategy, Tower Defense, Pixel Gra...
# 250180    [Arcade, Classic, Action, Co-op, Side Scroller...
# Name: tags, dtype: object

# %% [markdown]
# Now `tags` column contains lists with tags, so we need to transform this lists into separate columns and create one-hot encoded vector for each tag.

# %%
tags = pd.get_dummies(df["tags"].explode()).groupby(level = 0).sum()

tags.head()
# Out:
#         1980s  1990's  2.5D  2D  2D Fighter  2D Platformer  360 Video  3D  \
# app_id
# 10        1       1      0    0       0            0            0       0
# 20        0       1      0    0       0            0            0       0
# 30        0       0      0    0       0            0            0       0
# 40        0       1      0    0       0            0            0       0
# 50        0       1      0    0       0            0            0       0
#
#         3D Fighter  3D Platformer  3D Vision  4 Player Local  4X  6DOF  \
# app_id
# 10           0            0            0             0         0    0
# 20           0            0            0             0         0    0
# 30           0            0            0             0         0    0
# 40           0            0            0             0         0    0
# 50           0            0            0             0         0    0
#
#         8-bit Music  ATV  Abstract  Action  Action RPG  Action RTS  \
# app_id
# 10           0        0       0        1         0           0
# 20           0        0       0        1         0           0
# 30           0        0       0        1         0           0
# 40           0        0       0        1         0           0
# 50           0        0       0        1         0           0
#
#         Action Roguelike  Action-Adventure  Addictive  Adventure  Agriculture  \
# app_id
# 10              0                 0             0          0           0
# 20              0                 0             0          0           0
# 30              0                 0             0          0           0
# 40              0                 0             0          0           0
# 50              0                 0             0          1           0
#
#         Aliens  Alternate History  Ambient  America  Animation & Modeling  \
# app_id
# 10         0            0             0        0               0
# 20         0            0             0        0               0
# 30         0            0             0        0               0
# 40         0            0             0        0               0
# 50         1            0             0        0               0
#
#         Anime  Arcade  Archery  Arena Shooter  Artificial Intelligence  \
# app_id
# 10        0       0       0           0                   0
# 20        0       0       0           0                   0
# 30        0       0       0           0                   0
# 40        0       0       0           1                   0
# 50        0       0       0           0                   0
#
#         Assassin  Asymmetric VR  Asynchronous Multiplayer  Atmospheric  \
# app_id
# 10          1           0                    0                  0
# 20          0           0                    0                  0
# 30          0           0                    0                  0
# 40          0           0                    0                  0
# 50          0           0                    0                  1
#
#         Audio Production  Auto Battler  Automation  Automobile Sim  BMX  \
# app_id
# 10              0               0            0             0         0
# 20              0               0            0             0         0
# 30              0               0            0             0         0
# 40              0               0            0             0         0
# 50              0               0            0             0         0
#
#         Base Building  Baseball  Based On A Novel  Basketball  Battle Royale  \
# app_id
# 10            0            0             0              0            0
# 20            0            0             0              0            0
# 30            0            0             0              0            0
# 40            0            0             0              0            0
# 50            0            0             0              0            0
#
#         Beat 'em up  Beautiful  Benchmark  Bikes  Blood  Board Game  \
# app_id
# 10           0           0          0        0      0         0
# 20           0           0          0        0      0         0
# 30           0           0          0        0      0         0
# 40           0           0          0        0      0         0
# 50           0           0          0        0      0         0
#
#         Boss Rush  Bowling  Boxing  Building  Bullet Hell  Bullet Time  CRPG  \
# app_id
# 10          0         0        0        0          0            0         0
# 20          0         0        0        0          0            0         0
# 30          0         0        0        0          0            0         0
# 40          0         0        0        0          0            0         0
# 50          0         0        0        0          0            0         0
#
#         Capitalism  Card Battler  Card Game  Cartoon  Cartoony  Casual  Cats  \
# app_id
# 10           0            0           0         0         0        0      0
# 20           0            0           0         0         0        0      0
# 30           0            0           0         0         0        0      0
# 40           0            0           0         0         0        0      0
# 50           0            0           0         0         0        0      0
#
#         Character Action Game  Character Customization  Chess  Choices Matter  \
# app_id
# 10                0                       0               0           0
# 20                0                       0               0           0
# 30                0                       0               0           0
# 40                0                       0               0           0
# 50                0                       0               0           0
#
#         Choose Your Own Adventure  Cinematic  City Builder  Class-Based  \
# app_id
# 10                  0                  0            0            0
# 20                  0                  0            0            1
# 30                  0                  0            0            1
# 40                  0                  0            0            0
# 50                  0                  0            0            0
#
#         Classic  Clicker  Co-op  Co-op Campaign  Coding  Cold War  \
# app_id
# 10         1        0       0           0           0        0
# 20         1        0       1           0           0        0
# 30         1        0       1           0           0        0
# 40         1        0       1           0           0        0
# 50         1        0       1           0           0        0
#
#         Collectathon  Colony Sim  Colorful  Combat  Combat Racing  Comedy  \
# app_id
# 10            0            0          0        0          0           0
# 20            0            0          0        0          0           0
# 30            0            0          0        0          0           0
# 40            0            0          0        0          0           0
# 50            0            0          0        0          0           0
#
#         Comic Book  Competitive  Conspiracy  Controller  Conversation  \
# app_id
# 10           0           1            0           0            0
# 20           0           1            0           0            0
# 30           0           0            0           0            0
# 40           0           1            0           0            0
# 50           0           0            0           0            0
#
#         Cooking  Cozy  Crafting  Creature Collector  Cricket  Crime  \
# app_id
# 10         0       0       0              0             0       0
# 20         0       0       0              0             0       0
# 30         0       0       0              0             0       0
# 40         0       0       0              0             0       0
# 50         0       0       0              0             0       0
#
#         Crowdfunded  Cult Classic  Cute  Cyberpunk  Cycling  Dark  \
# app_id
# 10           0             0         0       0         0       0
# 20           0             0         0       0         0       0
# 30           0             0         0       0         0       0
# 40           0             0         0       0         0       0
# 50           0             0         0       0         0       0
#
#         Dark Comedy  Dark Fantasy  Dark Humor  Dating Sim  Deckbuilding  \
# app_id
# 10           0             0            0           0            0
# 20           0             0            0           0            0
# 30           0             0            0           0            0
# 40           0             0            0           0            0
# 50           0             0            0           0            0
#
#         Demons  Design & Illustration  Destruction  Detective  Difficult  \
# app_id
# 10         0              0                 0           0          0
# 20         0              0                 0           0          0
# 30         0              0                 0           0          1
# 40         0              0                 0           0          1
# 50         0              0                 0           0          0
#
#         Dinosaurs  Diplomacy  Documentary  Dog  Dragons  Drama  Driving  \
# app_id
# 10          0          0           0        0      0       0       0
# 20          0          0           0        0      0       0       0
# 30          0          0           0        0      0       0       0
# 40          0          0           0        0      0       0       0
# 50          0          0           0        0      0       0       0
#
#         Dungeon Crawler  Dungeons & Dragons  Dynamic Narration  Dystopian  \
# app_id
# 10             0                  0                  0              0
# 20             0                  0                  0              0
# 30             0                  0                  0              0
# 40             0                  0                  0              0
# 50             0                  0                  0              0
#
#         Early Access  Economy  Education  Electronic  Electronic Music  \
# app_id
# 10            0          0         0           0              0
# 20            0          0         0           0              0
# 30            0          0         0           0              0
# 40            0          0         0           0              0
# 50            0          0         0           0              0
#
#         Emotional  Epic  Episodic  Escape Room  Experience  Experimental  \
# app_id
# 10          0        0       0          0            0            0
# 20          0        0       0          0            0            0
# 30          0        0       0          0            0            0
# 40          0        0       0          0            0            0
# 50          0        0       0          0            0            0
#
#         Exploration  FMV  FPS  Faith  Family Friendly  Fantasy  Farming  \
# app_id
# 10           0        0    1     0           0            0        0
# 20           0        0    1     0           0            0        0
# 30           0        0    1     0           0            0        0
# 40           0        0    1     0           0            0        0
# 50           0        0    1     0           0            0        0
#
#         Farming Sim  Fast-Paced  Feature Film  Female Protagonist  Fighting  \
# app_id
# 10           0            0            0                0              0
# 20           0            1            0                0              0
# 30           0            0            0                0              0
# 40           0            1            0                0              0
# 50           0            0            0                0              0
#
#         First-Person  Fishing  Flight  Football (American)  Football (Soccer)  \
# app_id
# 10            1          0        0             0                   0
# 20            1          0        0             0                   0
# 30            1          0        0             0                   0
# 40            1          0        0             0                   0
# 50            1          0        0             0                   0
#
#         Foreign  Fox  Free to Play  Funny  Futuristic  Gambling  \
# app_id
# 10         0      0         0         0         0          0
# 20         0      0         0         1         0          0
# 30         0      0         0         0         0          0
# 40         0      0         0         0         0          0
# 50         0      0         0         0         0          0
#
#         Game Development  GameMaker  Games Workshop  Gaming  God Game  Golf  \
# app_id
# 10              0             0             0           0        0       0
# 20              0             0             0           0        0       0
# 30              0             0             0           0        0       0
# 40              0             0             0           0        0       0
# 50              0             0             0           0        0       0
#
#         Gore  Gothic  Grand Strategy  Great Soundtrack  Grid-Based Movement  \
# app_id
# 10        0      0           0                0                  0
# 20        0      0           0                0                  0
# 30        0      0           0                0                  0
# 40        1      0           0                0                  0
# 50        1      0           0                1                  0
#
#         Gun Customization  Hack and Slash  Hacking  Hand-drawn  Hardware  \
# app_id
# 10              0                 0           0          0          0
# 20              0                 0           0          0          0
# 30              0                 0           0          0          0
# 40              0                 0           0          0          0
# 50              0                 0           0          0          0
#
#         Heist  Hentai  Hero Shooter  Hex Grid  Hidden Object  Historical  \
# app_id
# 10        0       0          0           0           0             0
# 20        0       0          1           0           0             0
# 30        0       0          0           0           0             1
# 40        0       0          0           0           0             0
# 50        0       0          0           0           0             0
#
#         Hobby Sim  Hockey  Horror  Horses  Hunting  Idler  Illuminati  \
# app_id
# 10          0         0       0       0       0       0         0
# 20          0         0       0       0       0       0         0
# 30          0         0       0       0       0       0         0
# 40          0         0       0       0       0       0         0
# 50          0         0       0       0       0       0         0
#
#         Immersive  Immersive Sim  Indie  Instrumental Music  \
# app_id
# 10          0            0          0             0
# 20          0            0          0             0
# 30          0            0          0             0
# 40          0            0          0             0
# 50          0            0          0             0
#
#         Intentionally Awkward Controls  Interactive Fiction  \
# app_id
# 10                     0                         0
# 20                     0                         0
# 30                     0                         0
# 40                     0                         0
# 50                     0                         0
#
#         Inventory Management  Investigation  Isometric  JRPG  Jet  \
# app_id
# 10                0                 0            0        0    0
# 20                0                 0            0        0    0
# 30                0                 0            0        0    0
# 40                0                 0            0        0    0
# 50                0                 0            0        0    0
#
#         Job Simulator  Jump Scare  Kickstarter  LEGO  LGBTQ+  Lemmings  \
# app_id
# 10            0             0           0         0      0        0
# 20            0             0           0         0      0        0
# 30            0             0           0         0      0        0
# 40            0             0           0         0      0        0
# 50            0             0           0         0      0        0
#
#         Level Editor  Life Sim  Linear  Local Co-Op  Local Multiplayer  Logic  \
# app_id
# 10            0           0        0         0               0            0
# 20            0           0        0         0               0            0
# 30            0           0        0         0               0            0
# 40            0           0        0         0               0            0
# 50            0           0        0         0               0            0
#
#         Loot  Looter Shooter  Lore-Rich  Lovecraftian  MMORPG  MOBA  Magic  \
# app_id
# 10        0          0            0            0          0      0     0
# 20        0          0            0            0          0      0     0
# 30        0          0            0            0          0      0     0
# 40        0          0            0            0          0      0     0
# 50        0          0            0            0          0      0     0
#
#         Mahjong  Management  Mars  Martial Arts  Massively Multiplayer  \
# app_id
# 10         0          0        0         0                 0
# 20         0          0        0         0                 0
# 30         0          0        0         0                 0
# 40         0          0        0         0                 0
# 50         0          0        0         0                 0
#
#         Match 3  Mature  Mechs  Medical Sim  Medieval  Memes  Metroidvania  \
# app_id
# 10         0        0      0         0           0       0          0
# 20         0        0      0         0           0       0          0
# 30         0        0      0         0           0       0          0
# 40         0        0      0         0           0       0          0
# 50         0        0      0         0           0       0          0
#
#         Military  Mini Golf  Minigames  Minimalist  Mining  Mod  Moddable  \
# app_id
# 10          1         0          0           0         0     0       0
# 20          0         0          0           0         0     1       0
# 30          1         0          0           0         0     0       0
# 40          0         0          0           0         0     0       0
# 50          1         0          0           0         0     0       1
#
#         Modern  Motocross  Motorbike  Mouse only  Movie  Multiplayer  \
# app_id
# 10         0        0          0           0        0         1
# 20         0        0          0           0        0         1
# 30         0        0          0           0        0         1
# 40         0        0          0           0        0         1
# 50         0        0          0           0        0         0
#
#         Multiple Endings  Music  Music-Based Procedural Generation  Musou  \
# app_id
# 10              0           0                    0                    0
# 20              0           0                    0                    0
# 30              0           0                    0                    0
# 40              0           0                    0                    0
# 50              0           0                    0                    0
#
#         Mystery  Mystery Dungeon  Mythology  NSFW  Narration  Narrative  \
# app_id
# 10         0            0             0        0       0          0
# 20         0            0             0        0       0          0
# 30         0            0             0        0       0          0
# 40         0            0             0        0       0          0
# 50         0            0             0        0       0          0
#
#         Nature  Naval  Naval Combat  Ninja  Noir  Nonlinear  Nostalgia  \
# app_id
# 10         0      0          0         0      0       0          1
# 20         0      0          0         0      0       0          0
# 30         0      0          0         0      0       0          0
# 40         0      0          0         0      0       0          0
# 50         0      0          0         0      0       0          0
#
#         Nudity  Offroad  Old School  On-Rails Shooter  Online Co-Op  \
# app_id
# 10         0       0          1              0               0
# 20         0       0          1              0               1
# 30         0       0          1              0               0
# 40         0       0          1              0               0
# 50         0       0          0              0               0
#
#         Open World  Open World Survival Craft  Otome  Outbreak Sim  Parkour  \
# app_id
# 10           0                  0                0          0          0
# 20           0                  0                0          0          0
# 30           0                  0                0          0          0
# 40           0                  0                0          0          0
# 50           0                  0                0          0          0
#
#         Parody  Party  Party Game  Party-Based RPG  Perma Death  \
# app_id
# 10         0      0         0             0              0
# 20         0      0         0             0              0
# 30         0      0         0             0              0
# 40         0      0         0             0              0
# 50         0      0         0             0              0
#
#         Philosophical  Photo Editing  Physics  Pinball  Pirates  \
# app_id
# 10            0              0           0        0        0
# 20            0              0           0        0        0
# 30            0              0           0        0        0
# 40            0              0           0        0        0
# 50            0              0           0        0        0
#
#         Pixel Graphics  Platformer  Point & Click  Political  Political Sim  \
# app_id
# 10             0             0            0            0            0
# 20             0             0            0            0            0
# 30             0             0            0            0            0
# 40             0             0            0            0            0
# 50             0             0            0            0            0
#
#         Politics  Pool  Post-apocalyptic  Precision Platformer  \
# app_id
# 10          0       0           0                   0
# 20          0       0           0                   0
# 30          0       0           0                   0
# 40          0       0           0                   0
# 50          0       0           0                   0
#
#         Procedural Generation  Programming  Psychedelic  Psychological  \
# app_id
# 10                0                 0            0             0
# 20                0                 0            0             0
# 30                0                 0            0             0
# 40                0                 0            0             0
# 50                0                 0            0             0
#
#         Psychological Horror  Puzzle  Puzzle Platformer  PvE  PvP  \
# app_id
# 10                0              0            0           0    1
# 20                0              0            0           0    0
# 30                0              0            0           0    0
# 40                0              0            0           0    0
# 50                0              1            0           0    0
#
#         Quick-Time Events  RPG  RPGMaker  RTS  Racing  Real Time Tactics  \
# app_id
# 10              0           0       0      0      0            0
# 20              0           0       0      0      0            0
# 30              0           0       0      0      0            0
# 40              0           0       0      0      0            0
# 50              0           0       0      0      0            0
#
#         Real-Time  Real-Time with Pause  Realistic  Reboot  Relaxing  Remake  \
# app_id
# 10          0                0               0         0        0        0
# 20          0                0               0         0        0        1
# 30          0                0               0         0        0        0
# 40          0                0               0         0        0        0
# 50          0                0               0         0        0        0
#
#         Replay Value  Resource Management  Retro  Rhythm  Robots  Rock Music  \
# app_id
# 10            0                0             0       0       0         0
# 20            0                0             1       0       0         0
# 30            0                0             1       0       0         0
# 40            0                0             1       0       0         0
# 50            0                0             1       0       0         0
#
#         Roguelike  Roguelike Deckbuilder  Roguelite  Roguevania  Romance  \
# app_id
# 10          0                0                0           0         0
# 20          0                0                0           0         0
# 30          0                0                0           0         0
# 40          0                0                0           0         0
# 50          0                0                0           0         0
#
#         Rome  Rugby  Runner  Sailing  Sandbox  Satire  Sci-fi  Science  \
# app_id
# 10        0     0       0       0        0        0       0       0
# 20        0     0       0       0        0        0       0       0
# 30        0     0       0       0        0        0       0       0
# 40        0     0       0       0        0        0       1       0
# 50        0     0       0       0        0        0       1       0
#
#         Score Attack  Sequel  Sexual Content  Shoot 'Em Up  Shooter  \
# app_id
# 10            1          0           0              0          1
# 20            0          0           0              0          1
# 30            0          0           0              0          1
# 40            0          0           0              0          1
# 50            0          0           0              0          1
#
#         Shop Keeper  Short  Side Scroller  Silent Protagonist  Simulation  \
# app_id
# 10           0         0          0                 0               0
# 20           0         0          0                 0               0
# 30           0         0          0                 0               0
# 40           0         0          0                 0               0
# 50           0         0          0                 1               0
#
#         Singleplayer  Skateboarding  Skating  Skiing  Sniper  Snooker  Snow  \
# app_id
# 10            0             0           0        0       0       0       0
# 20            0             0           0        0       0       0       0
# 30            1             0           0        0       0       0       0
# 40            0             0           0        0       0       0       0
# 50            1             0           0        0       0       0       0
#
#         Snowboarding  Social Deduction  Software  Software Training  Sokoban  \
# app_id
# 10            0               0             0             0             0
# 20            0               0             0             0             0
# 30            0               0             0             0             0
# 40            0               0             0             0             0
# 50            0               0             0             0             0
#
#         Solitaire  Souls-like  Soundtrack  Space  Space Sim  Spaceships  \
# app_id
# 10          0           0           0        0        0           0
# 20          0           0           0        0        0           0
# 30          0           0           0        0        0           0
# 40          0           0           0        0        0           0
# 50          0           0           0        0        0           0
#
#         Spectacle fighter  Spelling  Split Screen  Sports  Stealth  \
# app_id
# 10              0              0           0          0       0
# 20              0              0           0          0       0
# 30              0              0           0          0       0
# 40              0              0           0          0       0
# 50              0              0           0          0       0
#
#         Steam Machine  Steampunk  Story Rich  Strategy  Strategy RPG  \
# app_id
# 10            0            0           0          1           0
# 20            0            0           0          0           0
# 30            0            0           0          1           0
# 40            0            0           0          0           0
# 50            0            0           1          0           0
#
#         Stylized  Submarine  Superhero  Supernatural  Surreal  Survival  \
# app_id
# 10          0         0          0            0          0         1
# 20          0         0          0            0          0         0
# 30          0         0          0            0          0         0
# 40          0         0          0            0          0         0
# 50          0         0          0            0          0         0
#
#         Survival Horror  Swordplay  Tabletop  Tactical  Tactical RPG  Tanks  \
# app_id
# 10             0             0          0         1           0         0
# 20             0             0          0         0           0         0
# 30             0             0          0         1           0         0
# 40             0             0          0         0           0         0
# 50             0             0          0         0           0         0
#
#         Team-Based  Tennis  Text-Based  Third Person  Third-Person Shooter  \
# app_id
# 10           1         0         0            0                 0
# 20           1         0         0            0                 0
# 30           1         0         0            0                 0
# 40           0         0         0            0                 0
# 50           0         0         0            0                 0
#
#         Thriller  Tile-Matching  Time Attack  Time Management  \
# app_id
# 10          0           0             0              0
# 20          0           0             0              0
# 30          0           0             0              0
# 40          0           0             0              0
# 50          0           0             0              0
#
#         Time Manipulation  Time Travel  Top-Down  Top-Down Shooter  \
# app_id
# 10              0               0           0             0
# 20              0               0           0             0
# 30              0               0           0             0
# 40              0               0           0             0
# 50              0               0           0             0
#
#         Touch-Friendly  Tower Defense  TrackIR  Trading  Trading Card Game  \
# app_id
# 10             0              0           0        0             0
# 20             0              0           0        0             0
# 30             0              0           0        0             0
# 40             0              0           0        0             0
# 50             0              0           0        0             0
#
#         Traditional Roguelike  Trains  Transhumanism  Transportation  Trivia  \
# app_id
# 10                0               0          0               0           0
# 20                0               0          0               0           0
# 30                0               0          0               0           0
# 40                0               0          0               0           0
# 50                0               0          0               0           0
#
#         Turn-Based  Turn-Based Combat  Turn-Based Strategy  \
# app_id
# 10           0              0                   0
# 20           0              0                   0
# 30           0              0                   0
# 40           0              0                   0
# 50           0              0                   0
#
#         Turn-Based Tactics  Tutorial  Twin Stick Shooter  Typing  Underground  \
# app_id
# 10               0              0              0             0         0
# 20               0              0              0             0         0
# 30               0              0              0             0         0
# 40               0              0              0             0         0
# 50               0              0              0             0         0
#
#         Underwater  Unforgiving  Utilities  VR  Vampire  Vehicular Combat  \
# app_id
# 10           0           0           0       0     0             0
# 20           0           0           0       0     0             0
# 30           0           0           0       0     0             0
# 40           0           0           0       0     0             0
# 50           0           0           0       0     0             0
#
#         Video Production  Vikings  Villain Protagonist  Violent  Visual Novel  \
# app_id
# 10              0            0              0              0           0
# 20              0            0              0              1           0
# 30              0            0              0              0           0
# 40              0            0              0              0           0
# 50              0            0              0              0           0
#
#         Voice Control  Volleyball  Voxel  Walking Simulator  War  Wargame  \
# app_id
# 10            0             0        0            0           0      0
# 20            0             0        0            0           0      0
# 30            0             0        0            0           1      0
# 40            0             0        0            0           0      0
# 50            0             0        0            0           0      0
#
#         Warhammer 40K  Web Publishing  Well-Written  Werewolves  Western  \
# app_id
# 10            0               0              0            0         0
# 20            0               0              0            0         0
# 30            0               0              0            0         0
# 40            0               0              0            0         0
# 50            0               0              0            0         0
#
#         Wholesome  Word Game  World War I  World War II  Wrestling  Zombies  \
# app_id
# 10          0          0           0             0           0         0
# 20          0          0           0             0           0         0
# 30          0          0           1             1           0         0
# 40          0          0           0             0           0         0
# 50          0          0           0             0           0         0
#
#         eSports
# app_id
# 10         1
# 20         0
# 30         0
# 40         0
# 50         0

# %% [markdown]
# Adding new tags to the dataset and saving for further use.

# %%
df = df.join(tags)

df.head()
# Out:
#                      title                date_release  \
# app_id
# 13500   Prince of Persia: Warrior Within™  2008-11-21
# 113020       Monaco: What's Yours Is Mine  2013-04-24
# 226560                 Escape Dead Island  2014-11-18
# 249050            Dungeon of the ENDLESS™  2014-10-27
# 250180                       METAL SLUG 3  2015-09-14
#
#                           description                      \
# app_id
# 13500   Enter the dark underworld of Prince of Persia ...
# 113020  Monaco: What's Yours Is Mine is a single playe...
# 226560  Escape Dead Island is a Survival-Mystery adven...
# 249050  Dungeon of the Endless is a Rogue-Like Dungeon...
# 250180  “METAL SLUG 3”, the masterpiece in SNK’s emble...
#
#                               tags                         \
# app_id
# 13500   [Action, Adventure, Parkour, Third Person, Gre...
# 113020  [Co-op, Stealth, Indie, Heist, Local Co-Op, St...
# 226560  [Zombies, Adventure, Survival, Action, Third P...
# 249050  [Roguelike, Strategy, Tower Defense, Pixel Gra...
# 250180  [Arcade, Classic, Action, Co-op, Side Scroller...
#
#                developers             rating      positive_ratio  \
# app_id
# 13500                   [Ubisoft]  Very Positive        84
# 113020        [Pocketwatch Games]  Very Positive        92
# 226560                 [Fatshark]          Mixed        61
# 249050        [AMPLITUDE Studios]  Very Positive        88
# 250180  [SNK CORPORATION, Dotemu]  Very Positive        90
#
#         user_reviews   win   mac   linux  steam_deck  price_final  \
# app_id
# 13500       2199      True  False  False     True         9.99
# 113020      3722      True   True   True     True        14.99
# 226560       873      True  False  False     True        14.99
# 249050      8784      True   True  False     True        11.99
# 250180      5579      True  False  False     True         7.99
#
#                           header_image                     1980s  1990's  \
# app_id
# 13500   https://cdn.akamai.steamstatic.com/steam/apps/...    0       0
# 113020  https://cdn.akamai.steamstatic.com/steam/apps/...    0       0
# 226560  https://cdn.akamai.steamstatic.com/steam/apps/...    0       0
# 249050  https://cdn.akamai.steamstatic.com/steam/apps/...    0       0
# 250180  https://cdn.akamai.steamstatic.com/steam/apps/...    0       0
#
#         2.5D  2D  2D Fighter  2D Platformer  360 Video  3D  3D Fighter  \
# app_id
# 13500     0    0       0            0            0       0       0
# 113020    0    1       0            0            0       0       0
# 226560    0    0       0            0            0       0       0
# 249050    0    1       0            0            0       0       0
# 250180    0    1       0            0            0       0       0
#
#         3D Platformer  3D Vision  4 Player Local  4X  6DOF  8-bit Music  ATV  \
# app_id
# 13500         0            0             0         0    0        0        0
# 113020        0            0             0         0    0        0        0
# 226560        0            0             0         0    0        0        0
# 249050        0            0             0         0    0        0        0
# 250180        0            0             0         0    0        0        0
#
#         Abstract  Action  Action RPG  Action RTS  Action Roguelike  \
# app_id
# 13500       0        1         0           0              0
# 113020      0        1         0           0              0
# 226560      0        1         0           0              0
# 249050      0        0         0           0              0
# 250180      0        1         0           0              0
#
#         Action-Adventure  Addictive  Adventure  Agriculture  Aliens  \
# app_id
# 13500           0             0          1           0          0
# 113020          0             0          1           0          0
# 226560          0             0          1           0          0
# 249050          0             0          1           0          0
# 250180          0             0          0           0          0
#
#         Alternate History  Ambient  America  Animation & Modeling  Anime  \
# app_id
# 13500           0             0        0               0             0
# 113020          0             0        0               0             0
# 226560          0             0        0               0             1
# 249050          0             0        0               0             0
# 250180          0             0        0               0             0
#
#         Arcade  Archery  Arena Shooter  Artificial Intelligence  Assassin  \
# app_id
# 13500      0       0           0                   0                 0
# 113020     0       0           0                   0                 0
# 226560     0       0           0                   0                 0
# 249050     0       0           0                   0                 0
# 250180     1       0           0                   0                 0
#
#         Asymmetric VR  Asynchronous Multiplayer  Atmospheric  \
# app_id
# 13500         0                    0                  1
# 113020        0                    0                  0
# 226560        0                    0                  1
# 249050        0                    0                  0
# 250180        0                    0                  0
#
#         Audio Production  Auto Battler  Automation  Automobile Sim  BMX  \
# app_id
# 13500           0               0            0             0         0
# 113020          0               0            0             0         0
# 226560          0               0            0             0         0
# 249050          0               0            0             0         0
# 250180          0               0            0             0         0
#
#         Base Building  Baseball  Based On A Novel  Basketball  Battle Royale  \
# app_id
# 13500         0            0             0              0            0
# 113020        0            0             0              0            0
# 226560        0            0             0              0            0
# 249050        0            0             0              0            0
# 250180        0            0             0              0            0
#
#         Beat 'em up  Beautiful  Benchmark  Bikes  Blood  Board Game  \
# app_id
# 13500        0           0          0        0      0         0
# 113020       0           0          0        0      0         0
# 226560       0           0          0        0      0         0
# 249050       0           0          0        0      0         0
# 250180       0           0          0        0      0         0
#
#         Boss Rush  Bowling  Boxing  Building  Bullet Hell  Bullet Time  CRPG  \
# app_id
# 13500       0         0        0        0          0            0         0
# 113020      0         0        0        0          0            0         0
# 226560      0         0        0        0          0            0         0
# 249050      0         0        0        0          0            0         0
# 250180      0         0        0        0          0            0         0
#
#         Capitalism  Card Battler  Card Game  Cartoon  Cartoony  Casual  Cats  \
# app_id
# 13500        0            0           0         0         0        0      0
# 113020       0            0           0         0         0        1      0
# 226560       0            0           0         0         1        0      0
# 249050       0            0           0         0         0        0      0
# 250180       0            0           0         0         0        0      0
#
#         Character Action Game  Character Customization  Chess  Choices Matter  \
# app_id
# 13500             0                       0               0           0
# 113020            0                       0               0           0
# 226560            0                       0               0           0
# 249050            0                       0               0           0
# 250180            0                       0               0           0
#
#         Choose Your Own Adventure  Cinematic  City Builder  Class-Based  \
# app_id
# 13500               0                  0            0            0
# 113020              0                  0            0            0
# 226560              0                  0            0            0
# 249050              0                  0            0            0
# 250180              0                  0            0            0
#
#         Classic  Clicker  Co-op  Co-op Campaign  Coding  Cold War  \
# app_id
# 13500      1        0       0           0           0        0
# 113020     0        0       1           0           0        0
# 226560     0        0       1           0           0        0
# 249050     0        0       1           0           0        0
# 250180     1        0       1           0           0        0
#
#         Collectathon  Colony Sim  Colorful  Combat  Combat Racing  Comedy  \
# app_id
# 13500         0            0          0        0          0           0
# 113020        0            0          0        0          0           0
# 226560        0            0          0        0          0           0
# 249050        0            0          0        0          0           0
# 250180        0            0          0        0          0           1
#
#         Comic Book  Competitive  Conspiracy  Controller  Conversation  \
# app_id
# 13500        0           0            0           1            0
# 113020       0           0            0           1            0
# 226560       0           0            0           0            0
# 249050       0           0            0           0            0
# 250180       0           0            0           0            0
#
#         Cooking  Cozy  Crafting  Creature Collector  Cricket  Crime  \
# app_id
# 13500      0       0       0              0             0       0
# 113020     0       0       0              0             0       1
# 226560     0       0       0              0             0       0
# 249050     0       0       0              0             0       0
# 250180     0       0       0              0             0       0
#
#         Crowdfunded  Cult Classic  Cute  Cyberpunk  Cycling  Dark  \
# app_id
# 13500        0             0         0       0         0       1
# 113020       0             0         0       0         0       0
# 226560       0             0         0       0         0       0
# 249050       0             0         0       0         0       0
# 250180       0             0         0       0         0       0
#
#         Dark Comedy  Dark Fantasy  Dark Humor  Dating Sim  Deckbuilding  \
# app_id
# 13500        0             1            0           0            0
# 113020       0             0            0           0            0
# 226560       0             0            0           0            0
# 249050       0             0            0           0            0
# 250180       0             0            0           0            0
#
#         Demons  Design & Illustration  Destruction  Detective  Difficult  \
# app_id
# 13500      0              0                 0           0          0
# 113020     0              0                 0           0          0
# 226560     0              0                 0           0          0
# 249050     0              0                 0           0          1
# 250180     0              0                 0           0          1
#
#         Dinosaurs  Diplomacy  Documentary  Dog  Dragons  Drama  Driving  \
# app_id
# 13500       0          0           0        0      0       0       0
# 113020      0          0           0        0      0       0       0
# 226560      0          0           0        0      0       0       0
# 249050      0          0           0        0      0       0       0
# 250180      0          0           0        0      0       0       0
#
#         Dungeon Crawler  Dungeons & Dragons  Dynamic Narration  Dystopian  \
# app_id
# 13500          0                  0                  0              0
# 113020         0                  0                  0              0
# 226560         0                  0                  0              0
# 249050         1                  0                  0              0
# 250180         0                  0                  0              0
#
#         Early Access  Economy  Education  Electronic  Electronic Music  \
# app_id
# 13500         0          0         0           0              0
# 113020        0          0         0           0              0
# 226560        0          0         0           0              0
# 249050        0          0         0           0              0
# 250180        0          0         0           0              0
#
#         Emotional  Epic  Episodic  Escape Room  Experience  Experimental  \
# app_id
# 13500       0        0       0          0            0            0
# 113020      0        0       0          0            0            0
# 226560      0        0       0          0            0            0
# 249050      0        0       0          0            0            0
# 250180      0        0       0          0            0            0
#
#         Exploration  FMV  FPS  Faith  Family Friendly  Fantasy  Farming  \
# app_id
# 13500        0        0    0     0           0            1        0
# 113020       0        0    0     0           0            0        0
# 226560       0        0    0     0           0            0        0
# 249050       0        0    0     0           0            0        0
# 250180       0        0    0     0           0            0        0
#
#         Farming Sim  Fast-Paced  Feature Film  Female Protagonist  Fighting  \
# app_id
# 13500        0            0            0                0              0
# 113020       0            0            0                0              0
# 226560       0            0            0                0              0
# 249050       0            0            0                0              0
# 250180       0            0            0                0              0
#
#         First-Person  Fishing  Flight  Football (American)  Football (Soccer)  \
# app_id
# 13500         0          0        0             0                   0
# 113020        0          0        0             0                   0
# 226560        0          0        0             0                   0
# 249050        0          0        0             0                   0
# 250180        0          0        0             0                   0
#
#         Foreign  Fox  Free to Play  Funny  Futuristic  Gambling  \
# app_id
# 13500      0      0         0         0         0          0
# 113020     0      0         0         0         0          0
# 226560     0      0         0         0         0          0
# 249050     0      0         0         0         0          0
# 250180     0      0         0         0         0          0
#
#         Game Development  GameMaker  Games Workshop  Gaming  God Game  Golf  \
# app_id
# 13500           0             0             0           0        0       0
# 113020          0             0             0           0        0       0
# 226560          0             0             0           0        0       0
# 249050          0             0             0           0        0       0
# 250180          0             0             0           0        0       0
#
#         Gore  Gothic  Grand Strategy  Great Soundtrack  Grid-Based Movement  \
# app_id
# 13500     1      0           0                1                  0
# 113020    0      0           0                1                  0
# 226560    1      0           0                0                  0
# 249050    0      0           0                1                  0
# 250180    0      0           0                1                  0
#
#         Gun Customization  Hack and Slash  Hacking  Hand-drawn  Hardware  \
# app_id
# 13500           0                 1           0          0          0
# 113020          0                 0           0          0          0
# 226560          0                 1           0          0          0
# 249050          0                 0           0          0          0
# 250180          0                 0           0          0          0
#
#         Heist  Hentai  Hero Shooter  Hex Grid  Hidden Object  Historical  \
# app_id
# 13500     0       0          0           0           0             0
# 113020    1       0          0           0           0             0
# 226560    0       0          0           0           0             0
# 249050    0       0          0           0           0             0
# 250180    0       0          0           0           0             0
#
#         Hobby Sim  Hockey  Horror  Horses  Hunting  Idler  Illuminati  \
# app_id
# 13500       0         0       0       0       0       0         0
# 113020      0         0       0       0       0       0         0
# 226560      0         0       1       0       0       0         0
# 249050      0         0       0       0       0       0         0
# 250180      0         0       0       0       0       0         0
#
#         Immersive  Immersive Sim  Indie  Instrumental Music  \
# app_id
# 13500       0            0          0             0
# 113020      0            0          1             0
# 226560      0            0          0             0
# 249050      0            0          1             0
# 250180      0            0          0             0
#
#         Intentionally Awkward Controls  Interactive Fiction  \
# app_id
# 13500                  0                         0
# 113020                 0                         0
# 226560                 0                         0
# 249050                 0                         0
# 250180                 0                         0
#
#         Inventory Management  Investigation  Isometric  JRPG  Jet  \
# app_id
# 13500             0                 0            0        0    0
# 113020            0                 0            0        0    0
# 226560            0                 0            0        0    0
# 249050            0                 0            0        0    0
# 250180            0                 0            0        0    0
#
#         Job Simulator  Jump Scare  Kickstarter  LEGO  LGBTQ+  Lemmings  \
# app_id
# 13500         0             0           0         0      0        0
# 113020        0             0           0         0      0        0
# 226560        0             0           0         0      0        0
# 249050        0             0           0         0      0        0
# 250180        0             0           0         0      0        0
#
#         Level Editor  Life Sim  Linear  Local Co-Op  Local Multiplayer  Logic  \
# app_id
# 13500         0           0        0         0               0            0
# 113020        0           0        0         1               1            0
# 226560        0           0        0         0               0            0
# 249050        0           0        0         0               0            0
# 250180        0           0        0         1               0            0
#
#         Loot  Looter Shooter  Lore-Rich  Lovecraftian  MMORPG  MOBA  Magic  \
# app_id
# 13500     0          0            0            0          0      0     0
# 113020    1          0            0            0          0      0     0
# 226560    0          0            0            0          0      0     0
# 249050    0          0            0            0          0      0     0
# 250180    0          0            0            0          0      0     0
#
#         Mahjong  Management  Mars  Martial Arts  Massively Multiplayer  \
# app_id
# 13500      0          0        0         0                 0
# 113020     0          0        0         0                 0
# 226560     0          0        0         0                 0
# 249050     0          0        0         0                 0
# 250180     0          0        0         0                 0
#
#         Match 3  Mature  Mechs  Medical Sim  Medieval  Memes  Metroidvania  \
# app_id
# 13500      0        0      0         0           0       0          0
# 113020     0        0      0         0           0       0          0
# 226560     0        0      0         0           0       0          0
# 249050     0        0      0         0           0       0          0
# 250180     0        0      0         0           0       0          0
#
#         Military  Mini Golf  Minigames  Minimalist  Mining  Mod  Moddable  \
# app_id
# 13500       0         0          0           0         0     0       0
# 113020      0         0          0           0         0     0       0
# 226560      0         0          0           0         0     0       0
# 249050      0         0          0           0         0     0       0
# 250180      0         0          0           0         0     0       0
#
#         Modern  Motocross  Motorbike  Mouse only  Movie  Multiplayer  \
# app_id
# 13500      0        0          0           0        0         0
# 113020     0        0          0           0        0         1
# 226560     0        0          0           0        0         1
# 249050     0        0          0           0        0         0
# 250180     0        0          0           0        0         1
#
#         Multiple Endings  Music  Music-Based Procedural Generation  Musou  \
# app_id
# 13500           0           0                    0                    0
# 113020          0           0                    0                    0
# 226560          0           0                    0                    0
# 249050          0           0                    0                    0
# 250180          0           0                    0                    0
#
#         Mystery  Mystery Dungeon  Mythology  NSFW  Narration  Narrative  \
# app_id
# 13500      0            0             0        0       0          0
# 113020     0            0             0        0       0          0
# 226560     0            0             0        0       0          0
# 249050     0            0             0        0       0          0
# 250180     0            0             0        0       0          0
#
#         Nature  Naval  Naval Combat  Ninja  Noir  Nonlinear  Nostalgia  \
# app_id
# 13500      0      0          0         0      0       0          0
# 113020     0      0          0         0      0       0          0
# 226560     0      0          0         0      0       0          0
# 249050     0      0          0         0      0       0          0
# 250180     0      0          0         0      0       0          1
#
#         Nudity  Offroad  Old School  On-Rails Shooter  Online Co-Op  \
# app_id
# 13500      0       0          0              0               0
# 113020     0       0          0              0               1
# 226560     0       0          0              0               0
# 249050     0       0          0              0               0
# 250180     0       0          1              0               1
#
#         Open World  Open World Survival Craft  Otome  Outbreak Sim  Parkour  \
# app_id
# 13500        1                  0                0          0          1
# 113020       0                  0                0          0          0
# 226560       1                  0                0          0          0
# 249050       0                  0                0          0          0
# 250180       0                  0                0          0          0
#
#         Parody  Party  Party Game  Party-Based RPG  Perma Death  \
# app_id
# 13500      0      0         0             0              0
# 113020     0      0         0             0              0
# 226560     0      0         0             0              0
# 249050     0      0         0             0              1
# 250180     0      0         0             0              0
#
#         Philosophical  Photo Editing  Physics  Pinball  Pirates  \
# app_id
# 13500         0              0           0        0        0
# 113020        0              0           0        0        0
# 226560        0              0           0        0        0
# 249050        0              0           0        0        0
# 250180        0              0           0        0        0
#
#         Pixel Graphics  Platformer  Point & Click  Political  Political Sim  \
# app_id
# 13500          0             1            0            0            0
# 113020         1             0            0            0            0
# 226560         0             0            0            0            0
# 249050         1             0            0            0            0
# 250180         1             1            0            0            0
#
#         Politics  Pool  Post-apocalyptic  Precision Platformer  \
# app_id
# 13500       0       0           0                   0
# 113020      0       0           0                   0
# 226560      0       0           0                   0
# 249050      0       0           0                   0
# 250180      0       0           0                   0
#
#         Procedural Generation  Programming  Psychedelic  Psychological  \
# app_id
# 13500             0                 0            0             0
# 113020            0                 0            0             0
# 226560            0                 0            0             0
# 249050            1                 0            0             0
# 250180            0                 0            0             0
#
#         Psychological Horror  Puzzle  Puzzle Platformer  PvE  PvP  \
# app_id
# 13500             0              1            0           0    0
# 113020            0              0            0           0    0
# 226560            0              0            0           0    0
# 249050            0              0            0           0    0
# 250180            0              0            0           0    0
#
#         Quick-Time Events  RPG  RPGMaker  RTS  Racing  Real Time Tactics  \
# app_id
# 13500           0           0       0      0      0            0
# 113020          0           0       0      0      0            0
# 226560          0           0       0      0      0            0
# 249050          0           1       0      0      0            0
# 250180          0           0       0      0      0            0
#
#         Real-Time  Real-Time with Pause  Realistic  Reboot  Relaxing  Remake  \
# app_id
# 13500       0                0               0         0        0        0
# 113020      0                0               0         0        0        0
# 226560      0                0               0         0        0        0
# 249050      0                0               0         0        0        0
# 250180      0                0               0         0        0        0
#
#         Replay Value  Resource Management  Retro  Rhythm  Robots  Rock Music  \
# app_id
# 13500         0                0             0       0       0         0
# 113020        0                0             0       0       0         0
# 226560        0                0             0       0       0         0
# 249050        1                1             0       0       0         0
# 250180        0                0             1       0       0         0
#
#         Roguelike  Roguelike Deckbuilder  Roguelite  Roguevania  Romance  \
# app_id
# 13500       0                0                0           0         0
# 113020      0                0                0           0         0
# 226560      0                0                0           0         0
# 249050      1                0                1           0         0
# 250180      0                0                0           0         0
#
#         Rome  Rugby  Runner  Sailing  Sandbox  Satire  Sci-fi  Science  \
# app_id
# 13500     0     0       0       0        0        0       0       0
# 113020    0     0       0       0        0        0       0       0
# 226560    0     0       0       0        0        0       0       0
# 249050    0     0       0       0        0        0       1       0
# 250180    0     0       0       0        0        0       0       0
#
#         Score Attack  Sequel  Sexual Content  Shoot 'Em Up  Shooter  \
# app_id
# 13500         0          0           0              0          0
# 113020        0          0           0              0          0
# 226560        0          0           0              0          0
# 249050        0          0           0              0          0
# 250180        0          0           0              1          1
#
#         Shop Keeper  Short  Side Scroller  Silent Protagonist  Simulation  \
# app_id
# 13500        0         0          0                 0               0
# 113020       0         0          0                 0               0
# 226560       0         0          0                 0               0
# 249050       0         0          0                 0               0
# 250180       0         0          1                 0               0
#
#         Singleplayer  Skateboarding  Skating  Skiing  Sniper  Snooker  Snow  \
# app_id
# 13500         1             0           0        0       0       0       0
# 113020        1             0           0        0       0       0       0
# 226560        1             0           0        0       0       0       0
# 249050        1             0           0        0       0       0       0
# 250180        1             0           0        0       0       0       0
#
#         Snowboarding  Social Deduction  Software  Software Training  Sokoban  \
# app_id
# 13500         0               0             0             0             0
# 113020        0               0             0             0             0
# 226560        0               0             0             0             0
# 249050        0               0             0             0             0
# 250180        0               0             0             0             0
#
#         Solitaire  Souls-like  Soundtrack  Space  Space Sim  Spaceships  \
# app_id
# 13500       0           0           0        0        0           0
# 113020      0           0           0        0        0           0
# 226560      0           0           0        0        0           0
# 249050      0           0           0        0        0           0
# 250180      0           0           0        0        0           0
#
#         Spectacle fighter  Spelling  Split Screen  Sports  Stealth  \
# app_id
# 13500           0              0           0          0       0
# 113020          0              0           0          0       1
# 226560          0              0           0          0       1
# 249050          0              0           0          0       0
# 250180          0              0           0          0       0
#
#         Steam Machine  Steampunk  Story Rich  Strategy  Strategy RPG  \
# app_id
# 13500         0            0           1          0           0
# 113020        0            0           0          1           0
# 226560        0            0           0          0           0
# 249050        0            0           0          1           0
# 250180        0            0           0          0           0
#
#         Stylized  Submarine  Superhero  Supernatural  Surreal  Survival  \
# app_id
# 13500       0         0          0            0          0         0
# 113020      0         0          0            0          0         0
# 226560      0         0          0            0          0         1
# 249050      0         0          0            0          0         1
# 250180      0         0          0            0          0         0
#
#         Survival Horror  Swordplay  Tabletop  Tactical  Tactical RPG  Tanks  \
# app_id
# 13500          0             0          0         0           0         0
# 113020         0             0          0         0           0         0
# 226560         1             0          0         0           0         0
# 249050         0             0          0         0           0         0
# 250180         0             0          0         0           0         0
#
#         Team-Based  Tennis  Text-Based  Third Person  Third-Person Shooter  \
# app_id
# 13500        0         0         0            1                 0
# 113020       0         0         0            0                 0
# 226560       0         0         0            1                 1
# 249050       0         0         0            0                 0
# 250180       0         0         0            0                 0
#
#         Thriller  Tile-Matching  Time Attack  Time Management  \
# app_id
# 13500       0           0             0              0
# 113020      0           0             0              0
# 226560      0           0             0              0
# 249050      0           0             0              0
# 250180      0           0             0              0
#
#         Time Manipulation  Time Travel  Top-Down  Top-Down Shooter  \
# app_id
# 13500           1               1           0             0
# 113020          0               0           1             0
# 226560          0               0           0             0
# 249050          0               0           0             0
# 250180          0               0           0             0
#
#         Touch-Friendly  Tower Defense  TrackIR  Trading  Trading Card Game  \
# app_id
# 13500          0              0           0        0             0
# 113020         0              0           0        0             0
# 226560         0              0           0        0             0
# 249050         0              1           0        0             0
# 250180         0              0           0        0             0
#
#         Traditional Roguelike  Trains  Transhumanism  Transportation  Trivia  \
# app_id
# 13500             0               0          0               0           0
# 113020            0               0          0               0           0
# 226560            0               0          0               0           0
# 249050            0               0          0               0           0
# 250180            0               0          0               0           0
#
#         Turn-Based  Turn-Based Combat  Turn-Based Strategy  \
# app_id
# 13500        0              0                   0
# 113020       0              0                   0
# 226560       0              0                   0
# 249050       0              0                   0
# 250180       0              0                   0
#
#         Turn-Based Tactics  Tutorial  Twin Stick Shooter  Typing  Underground  \
# app_id
# 13500            0              0              0             0         0
# 113020           0              0              0             0         0
# 226560           0              0              0             0         0
# 249050           0              0              0             0         0
# 250180           0              0              0             0         0
#
#         Underwater  Unforgiving  Utilities  VR  Vampire  Vehicular Combat  \
# app_id
# 13500        0           0           0       0     0             0
# 113020       0           0           0       0     0             0
# 226560       0           0           0       0     0             0
# 249050       0           0           0       0     0             0
# 250180       0           0           0       0     0             0
#
#         Video Production  Vikings  Villain Protagonist  Violent  Visual Novel  \
# app_id
# 13500           0            0              0              0           0
# 113020          0            0              0              0           0
# 226560          0            0              0              0           0
# 249050          0            0              0              0           0
# 250180          0            0              0              0           0
#
#         Voice Control  Volleyball  Voxel  Walking Simulator  War  Wargame  \
# app_id
# 13500         0             0        0            0           0      0
# 113020        0             0        0            0           0      0
# 226560        0             0        0            0           0      0
# 249050        0             0        0            0           0      0
# 250180        0             0        0            0           0      0
#
#         Warhammer 40K  Web Publishing  Well-Written  Werewolves  Western  \
# app_id
# 13500         0               0              0            0         0
# 113020        0               0              0            0         0
# 226560        0               0              0            0         0
# 249050        0               0              0            0         0
# 250180        0               0              0            0         0
#
#         Wholesome  Word Game  World War I  World War II  Wrestling  Zombies  \
# app_id
# 13500       0          0           0             0           0         0
# 113020      0          0           0             0           0         0
# 226560      0          0           0             0           0         1
# 249050      0          0           0             0           0         0
# 250180      0          0           0             0           0         0
#
#         eSports
# app_id
# 13500      0
# 113020     0
# 226560     0
# 249050     0
# 250180     0

# %%
df.to_parquet("recommender_files/data/gameset_ohe.parquet")

# %% [markdown]
# ### Checking results
#
# We can build our recommender in form of the table and check it's work.
#
# Some of supported genres are:
#
# `Action, Arcade, Rhythm, Fighting, First-Person, Third-Person, Hack and Slash, Platformer, Runner, Shooter, Bullet Hell, Adventure, Casual, Hidden Object, Metroidvania, Puzzle, Story Rich, Visual Novel, RPG, Adventure, Roguelike, Strategy, Simulation, Dating Sim, Immersive, Strategy, Card Game, Board Game, City Builder, Military, Tower Defense, Sports, Racing`
#
# *In case you want to try yourself.*

# %%
# enter any genre here
genre = "Action"

import pandas as pd
df = pd.read_parquet("recommender_files/data/gameset_ohe.parquet")

table = df.loc[(df[genre] == 1) & (df["rating"] == "Overwhelmingly Positive") |
       (df["rating"] == "Very Positive") |
       (df["rating"] == "Positive")].sort_values(by =
                                                ["user_reviews",
                                                 "positive_ratio"],
                                                 ascending = False)[:25]

table.head(25)
# Out:
#                                   title date_release  \
# app_id
# 304930                         Unturned   2017-07-07
# 1281930                      tModLoader   2020-05-16
# 319630      Life is Strange - Episode 1   2015-01-29
# 700330           SCP: Secret Laboratory   2017-12-29
# 1782210                       Crab Game   2021-10-29
# 1625450                            Muck   2021-06-05
# 10                       Counter-Strike   2000-11-01
# 203160                      Tomb Raider   2013-03-04
# 220                         Half-Life 2   2007-10-10
# 48700            Mount & Blade: Warband   2010-03-31
# 677620                        Splitgate   2019-05-24
# 1057090   Ori and the Will of the Wisps   2020-03-10
# 240              Counter-Strike: Source   2004-11-01
# 1506830                         FIFA 22   2021-09-30
# 391220         Rise of the Tomb Raider™   2016-02-09
# 1818750                     MultiVersus   2022-07-19
# 1046930                 Dota Underlords   2019-06-20
# 714010                          Aimlabs   2023-06-16
# 225540                    Just Cause™ 3   2015-11-30
# 629760                          MORDHAU   2019-04-29
# 222880                       Insurgency   2014-01-22
# 220240                        Far Cry 3   2012-12-04
# 211820                        Starbound   2016-07-22
# 221380         Age of Empires II (2013)   2013-04-09
# 823130   Totally Accurate Battlegrounds   2018-06-05
#
#                                                description  \
# app_id
# 304930   You're a survivor in the zombie infested ruins...
# 1281930  Dig, Fight, and Build your way through the wor...
# 319630   Episode 1 now FREE! Life is Strange is an awar...
# 700330   Deep within the SCP Foundation during a contai...
# 1782210  Crab Game is a First-Person Multiplayer game w...
# 1625450  Muck is a survival-roguelike. Collect resource...
# 10       Play the world's number 1 online action game. ...
# 203160   Tomb Raider explores the intense origin story ...
# 220      1998. HALF-LIFE sends a shock through the game...
# 48700    In a land torn asunder by incessant warfare, i...
# 677620   Splitgate is a free-to-play, fast-paced multip...
# 1057090  Play the critically acclaimed masterpiece. Emb...
# 240      Counter-Strike: Source blends Counter-Strike's...
# 1506830  Powered by Football™, EA SPORTS™ FIFA 22 bring...
# 391220   Rise of the Tomb Raider: 20 Year Celebration i...
# 1818750  MultiVersus is a free-to-play platform fighter...
# 1046930  Hire a crew and destroy your rivals in this ne...
# 714010   Aimlabs is the aim trainer of choice for over ...
# 225540   With over 1000 km² of complete freedom from sk...
# 629760   MORDHAU is a multiplayer medieval slasher. Cre...
# 222880   Take to the streets for intense close quarters...
# 220240   Discover the dark secrets of a lawless island ...
# 211820   You’ve fled your home, only to find yourself l...
# 221380   Age of Empires II has been re-imagined in high...
# 823130   Grab your balloon crossbow and trusty inflatab...
#
#                                                       tags  \
# app_id
# 304930   [Free to Play, Survival, Zombies, Multiplayer,...
# 1281930  [Adventure, Action, Free to Play, Indie, RPG, ...
# 319630   [Story Rich, Choices Matter, Great Soundtrack,...
# 700330   [Free to Play, Horror, Multiplayer, First-Pers...
# 1782210  [Psychological Horror, Multiplayer, Free to Pl...
# 1625450  [Survival, Crafting, Multiplayer, Building, Ro...
# 10       [Action, FPS, Multiplayer, Shooter, Classic, T...
# 203160   [Adventure, Action, Female Protagonist, Third ...
# 220      [FPS, Action, Sci-fi, Classic, Singleplayer, S...
# 48700    [Medieval, RPG, Open World, Strategy, Sandbox,...
# 677620   [Free to Play, FPS, Multiplayer, Arena Shooter...
# 1057090  [Beautiful, Metroidvania, Great Soundtrack, Pl...
# 240      [Shooter, Action, FPS, Multiplayer, Team-Based...
# 1506830  [Football (Soccer), Sports, Multiplayer, Contr...
# 391220   [Adventure, Action, Female Protagonist, Single...
# 1818750  [Multiplayer, 2D Fighter, Co-op, Action, Compe...
# 1046930  [Free to Play, Strategy, Casual, Auto Battler,...
# 714010   [Free to Play, FPS, Shooter, Simulation, First...
# 225540   [Open World, Action, Destruction, Third-Person...
# 629760   [Medieval, Multiplayer, First-Person, Swordpla...
# 222880   [FPS, Realistic, Tactical, Multiplayer, Shoote...
# 220240   [Open World, FPS, Action, Adventure, Multiplay...
# 211820   [Open World Survival Craft, Sandbox, Survival,...
# 221380   [Strategy, RTS, Medieval, Multiplayer, Classic...
# 823130   [Multiplayer, Physics, Indie, Character Custom...
#
#                                                 developers  \
# app_id
# 304930                             [Smartly Dressed Games]
# 1281930                                               None
# 319630   [DONTNOD Entertainment, Feral Interactive (Mac...
# 700330                                 [Northwood Studios]
# 1782210                                             [Dani]
# 1625450                                             [Dani]
# 10                                                 [Valve]
# 203160   [Crystal Dynamics, Eidos-Montréal, Feral Inter...
# 220                                                [Valve]
# 48700                           [TaleWorlds Entertainment]
# 677620                                        [1047 Games]
# 1057090                                [Moon Studios GmbH]
# 240                                                [Valve]
# 1506830                           [EA Canada & EA Romania]
# 391220   [Crystal Dynamics, Eidos-Montréal, Feral Inter...
# 1818750                               [Player First Games]
# 1046930                                            [Valve]
# 714010                                        [Statespace]
# 225540                                 [Avalanche Studios]
# 629760                                        [Triternion]
# 222880                             [New World Interactive]
# 220240   [Ubisoft Montreal, Massive Entertainment, and ...
# 211820                                       [Chucklefish]
# 221380   [Skybox Labs, Hidden Path Entertainment, Ensem...
# 823130                                          [Landfall]
#
#                           rating  positive_ratio  user_reviews   win    mac  \
# app_id
# 304930             Very Positive              91        515016  True   True
# 1281930  Overwhelmingly Positive              97        188684  True   True
# 319630   Overwhelmingly Positive              96        160660  True   True
# 700330             Very Positive              91        154538  True  False
# 1782210            Very Positive              92        144524  True   True
# 1625450            Very Positive              94        139841  True   True
# 10       Overwhelmingly Positive              97        136118  True   True
# 203160   Overwhelmingly Positive              96        136055  True   True
# 220      Overwhelmingly Positive              97        122230  True   True
# 48700    Overwhelmingly Positive              97        118732  True   True
# 677620             Very Positive              91        108046  True  False
# 1057090  Overwhelmingly Positive              96        104440  True  False
# 240      Overwhelmingly Positive              96        103720  True   True
# 1506830            Very Positive              80         95584  True  False
# 391220             Very Positive              94         94812  True   True
# 1818750            Very Positive              87         92833  True  False
# 1046930            Very Positive              82         89776  True   True
# 714010             Very Positive              93         89133  True  False
# 225540             Very Positive              83         88730  True  False
# 629760             Very Positive              81         88130  True  False
# 222880             Very Positive              91         86206  True   True
# 220240             Very Positive              89         82840  True  False
# 211820             Very Positive              91         82805  True   True
# 221380   Overwhelmingly Positive              95         79956  True  False
# 823130             Very Positive              88         76790  True  False
#
#          ...  Well-Written  Werewolves  Western Wholesome  Word Game  \
# app_id   ...
# 304930   ...             0           0        0         0          0
# 1281930  ...             0           0        0         0          0
# 319630   ...             0           0        0         0          0
# 700330   ...             0           0        0         0          0
# 1782210  ...             0           0        0         0          0
# 1625450  ...             0           0        0         0          0
# 10       ...             0           0        0         0          0
# 203160   ...             0           0        0         0          0
# 220      ...             0           0        0         0          0
# 48700    ...             0           0        0         0          0
# 677620   ...             0           0        0         0          0
# 1057090  ...             0           0        0         0          0
# 240      ...             0           0        0         0          0
# 1506830  ...             0           0        0         0          0
# 391220   ...             0           0        0         0          0
# 1818750  ...             0           0        0         0          0
# 1046930  ...             0           0        0         0          0
# 714010   ...             0           0        0         0          0
# 225540   ...             0           0        0         0          0
# 629760   ...             0           0        0         0          0
# 222880   ...             0           0        0         0          0
# 220240   ...             0           0        0         0          0
# 211820   ...             0           0        0         0          0
# 221380   ...             0           0        0         0          0
# 823130   ...             0           0        0         0          0
#
#          World War I  World War II  Wrestling  Zombies  eSports
# app_id
# 304930             0             0          0        1        0
# 1281930            0             0          0        0        0
# 319630             0             0          0        0        0
# 700330             0             0          0        0        0
# 1782210            0             0          0        0        0
# 1625450            0             0          0        0        0
# 10                 0             0          0        0        1
# 203160             0             0          0        0        0
# 220                0             0          0        1        0
# 48700              0             0          0        0        0
# 677620             0             0          0        0        1
# 1057090            0             0          0        0        0
# 240                0             0          0        0        1
# 1506830            0             0          0        0        1
# 391220             0             0          0        0        0
# 1818750            0             0          0        0        0
# 1046930            0             0          0        0        0
# 714010             0             0          0        0        1
# 225540             0             0          0        0        0
# 629760             0             0          0        0        0
# 222880             0             0          0        0        0
# 220240             0             0          0        0        0
# 211820             0             0          0        0        0
# 221380             0             0          0        0        0
# 823130             0             0          0        0        0
#
# [25 rows x 455 columns]

# %% [markdown]
# ### Running the app

# %% [markdown]
# Creating code for the application.
#
# In short, this are the steps performed in the code cell:
# 1. We create a form where the user can type their preferred genre, or select it from (very long) list of possible options and than request the recommendations.
#     - If user did not chose the genre and requested recommendations we'll kindly ask them again to choose one.
# 2. Than we filter the dataset so it contains only apps with "Positive" and higher ratings, sort values by *number of user reviews* and *positive reviews ratio* in descending order and crop this sorted dataset to top 25 data entries.
#     - It is done so because it's important, whether an app with 1000 reviews has a big positive reviews ratio or an app with 10 reviews has a big positive reviews ratio.
# 3. Finally, we show selected apps to the user, along with their rating, image, release date and supported platforms.

# %%
# %%writefile recommender_files/kb_recommender_by_genre.py

def top_25_games():
    import streamlit as st
    import pandas as pd

    df = pd.read_parquet("recommender_files/data/gameset_ohe.parquet")

    with st.form("my_form"):

        st.title("Top-25 games by Genre")

        # creating a form to select a genre
        genre = st.selectbox("Genre:",
                        options = df.columns[14:],
                        index = None,
                        placeholder = "Start typing to search among options")
        st.write('You selected:', genre)


        submitted = st.form_submit_button("Recommend")

        # kindly ask for genre if none was provided
        if submitted:
            if genre == None:
                st.write("Please, consider choosing a genre")
            # proceed if genre was provided
            else:
                # filtering the dataset and sorting values in descending order
                table = df.loc[(df[genre] == 1) &
                               (df["rating"] == "Overwhelmingly Positive") |
                                (df["rating"] == "Very Positive") |
                                (df["rating"] == "Positive")].sort_values(by =
                                                               ["user_reviews",
                                                                "positive_ratio"],
                                                                ascending = False)[:25]

                platforms = ["Windows", "MacOS", "Linux", "SteamDeck"]

                # showing top 25 games from sorted dataset
                for index in table.index:

                    supported_platforms = list(df.loc[index, ["win", "mac", "linux", "steam_deck"]])
                    supported_platforms = list(zip(platforms, supported_platforms))
                    supported_platforms = [i[0] for i in supported_platforms if i[1] == True]


                    # creating an information card for each of the games
                    with st.container():

                        st.header(table.loc[index, "title"], divider = "rainbow")

                        col1, col2 = st.columns([1, 2])

                        with col1:
                            st.image(table.loc[index, "header_image"])

                        with col2:
                            st.subheader(f"_Rating_: :green[ {table.loc[index, 'rating']} ]")
                            st.text(f"Reliase date: {table.loc[index, 'date_release']}")
                            st.text(("Supported plarforms: " + ", ".join(supported_platforms)))

top_25_games()
# Out:
# Overwriting recommender_files/kb_recommender_by_genre.py

# %% [markdown]
# You can run the app by running the code in the next cell.
#
# To enter the server with the app, please:
# 1. Copy the numbers in the first line of the output.
#     - ![1.jpeg](https://i.ibb.co/t4BHH52/1.jpg")
# 2. Click on the generated link in the very bottom of the output.
#     - ![2.jpeg](https://i.ibb.co/528T9mv/2.jpg)
# 3. Enter copied numbers in the text field and click submit.
#     - ![3.jpeg](https://i.ibb.co/d6Z3fs8/3.jpg)
# 4. After closing the application tab, don't forget to stop the cell execution.
#     - ![4.jpeg](https://i.ibb.co/2FJ7L62/4.jpg)

# %%
# !pip install streamlit &> /dev/null
# !npm install localtunnel &> /dev/null

# !streamlit run recommender_files/kb_recommender_by_genre.py & >/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com

# %% [markdown]
# ## Content-Based Recommender Using Title Descriptions

# %%
# restarting the Colab kernel to free all RAM
import os
os._exit(00)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading Saved Dataset

# %% [markdown]
# Loading the dataset without one-hot encoded tags.

# %%
df = pd.read_parquet("recommender_files/data/gameset.parquet")

# %% [markdown]
# For this recommender we'll pick apps with ratings from "Mixed" to "Overwhelmingly Positive" and sort the data in descending order again, because we'll need to crop it later.

# %%
# ts stands for truncated set

ts = df.loc[(df["rating"] == "Overwhelmingly Positive") |
            (df["rating"] == "Very Positive") |
            (df["rating"] == "Positive") |
            (df["rating"] == "Mostly Positive") |
            (df["rating"] == "Mixed")].sort_values(by =
                                                  ["user_reviews",
                                                   "positive_ratio"],
                                                   ascending = False)

ts = ts["description"].copy()

ts.head()
# Out:
# app_id
# 304930     You're a survivor in the zombie infested ruins...
# 433850     Z1 Battle Royale is a Free to Play, fast-paced...
# 1281930    Dig, Fight, and Build your way through the wor...
# 1468810    Tale of Immortal is an open-world sandbox base...
# 698780     The Literature Club is full of cute girls! Wil...
# Name: description, dtype: object

# %% [markdown]
# ### Creating Document Vectors
#
# For this recommender we'll need to measure how similar are descriptions of different games to one another.
# Cosine similarity can help us to find that measure, but before computing it we need to convert text of the descriptions into vectors of numbers.
#
# TF-IDF Vectorizer is suited perfectly for this case because we don't want to give a lot of weight to the words that appear very often - we would rather assign more value to the words that are specific to the description of each particular game.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(strip_accents = "unicode", stop_words = "english")

# %% [markdown]
# Converting descriptions into vectors.
#
# ***! Note on cropping***
#
# Computing cosine similarity is computationally quite expensive - most importantly, it takes a lot of RAM.
#
# The dataset is cropped to top 31500 data entries so it could fit in 12.7 GB of (free) Colab RAM.
#
# (*If you have more RAM feel free to remove this and any further slicing and use the whole dataset*).

# %%
tfidf_matrix = tfidf.fit_transform(ts[:31500])

# %% [markdown]
# ### Computing Cosine Similarities.
#
# Since previously we used TF-IDF Vectorizer on descriptions, computing simpler and less expensive linear kernel will suffice.

# %%
from sklearn.metrics.pairwise import linear_kernel

cosine_similarity = linear_kernel(tfidf_matrix)

# %% [markdown]
# Converting cosine similarity matrix into a dataset along with app ids, for easier reference.

# %%
# don't forget to remove slicing, in case of computing cosine similarity for the whole dataset
csf = pd.DataFrame(list(zip(ts[:31500].index, cosine_similarity)))
csf.columns = ["app_id", "cosine_similarity"]
csf = csf.set_index("app_id")

# %% [markdown]
# Saving dataset for later use in the application.
#
# (*In case you have computed cosine similarity for the whole dataset, you can uncomment and run the code in the code cell bellow to save your dataset. You can also save and then load it as one file, but it will slow down execution of the app.*)

# %%
# csf[:7875].to_parquet("recommender_files/cosine similarities/descriptions/cosine_similarity.parquet")
# csf[7875:15750].to_parquet("recommender_files/cosine similarities/descriptions/cosine_similarity2.parquet")
# csf[15750:23625].to_parquet("recommender_files/cosine similarities/descriptions/cosine_similarity3.parquet")
# csf[23625:].to_parquet("recommender_files/cosine similarities/descriptions/cosine_similarity4.parquet")

# %% [markdown]
# ### Checking results

# %% [markdown]
# We can look at the results in form of the table.
#
# *Change the value of the `game_title` variable, in case you want to try yourself, but be careful - selected title might not be in the dataset, since there are less data entries now.*
#
# (*If kernel shuts down just run the cell one more time.*)

# %%
# enter game title here
game_title = "Prince of Persia: Warrior Within™"

import pandas as pd
df = pd.read_parquet("recommender_files/data/gameset.parquet")

csf = pd.read_parquet("recommender_files/cosine similarities/descriptions/cosine_similarity.parquet")
for i in range(2, 5):
    csf = pd.concat([csf, pd.read_parquet(f"recommender_files/cosine similarities/descriptions/cosine_similarity{i}.parquet")])


ts = df.loc[(df["rating"] == "Overwhelmingly Positive") |
            (df["rating"] == "Very Positive") |
            (df["rating"] == "Positive") |
            (df["rating"] == "Mostly Positive") |
            (df["rating"] == "Mixed")].sort_values(by =
                                                  ["user_reviews",
                                                   "positive_ratio"],
                                                   ascending = False)

ts = ts[["title", "date_release", "rating", "win", "mac",
         "linux", "steam_deck", "price_final", "header_image"]][:31500]

game_id = ts.loc[ts["title"] == game_title].index

cosine_similarity = csf.loc[game_id, "cosine_similarity"].values[0]
cosine_similarity = list(zip(cosine_similarity, csf.index))
cosine_similarity = sorted(cosine_similarity, reverse = True)

ids = [i[1] for i in cosine_similarity[1:26]]

table = ts.loc[ids]

display(table.head(25))

del([df, csf, ts, game_id, cosine_similarity, ids, table])
# Out:
#                                                      title date_release  \
# app_id
# 19980                                    Prince of Persia®   2008-12-10
# 33320               Prince of Persia: The Forgotten Sands™   2010-06-08
# 621080                    Persian Nights: Sands of Wonders   2017-06-29
# 13530                   Prince of Persia: The Two Thrones™   2008-11-21
# 1550840                                              RATUZ   2022-04-22
# 499100   Dark Parables: The Exiled Prince Collector's E...   2016-08-09
# 13600                 Prince of Persia®: The Sands of Time   2008-11-21
# 545830              Princess of Tavern Collector's Edition   2017-10-23
# 1846940                               There Won't be Light   2022-09-25
# 1851570                                       Umbra Galaxy   2022-02-14
# 217270                                            Karateka   2012-12-03
# 858050                                 The Rose of Segunda   2018-05-30
# 252710                       The Last Express Gold Edition   2013-11-21
# 1695480                                        Hellblusser   2021-08-10
# 1583410                                            Hamster   2021-05-17
# 1079790                                         Orc Colony   2019-06-14
# 710030                         Cinderella Escape 2 Revenge   2017-10-06
# 611850                            Tragedy of Prince Rupert   2017-07-26
# 1266100     Vampire: The Masquerade — Parliament of Knives   2021-10-28
# 439770                    The Lost Heir: The Fall of Daria   2016-01-29
# 694770                  Vestaria Saga I: War of the Scions   2019-12-27
# 341680                                              stratO   2015-06-01
# 914290                               Welcome to Princeland   2018-11-09
# 1019590                       Lovely Planet 2: April Skies   2019-06-18
# 690640                       Trine 4: The Nightmare Prince   2019-10-08
#
#                   rating   win    mac  linux  steam_deck  price_final  \
# app_id
# 19980    Mostly Positive  True  False  False        True         9.99
# 33320              Mixed  True  False  False        True         9.99
# 621080     Very Positive  True   True   True        True         9.99
# 13530    Mostly Positive  True  False  False        True         9.99
# 1550840    Very Positive  True  False  False        True         5.99
# 499100     Very Positive  True  False  False        True         9.99
# 13600      Very Positive  True  False  False        True         9.99
# 545830             Mixed  True   True  False        True         9.99
# 1846940            Mixed  True  False  False        True         1.99
# 1851570         Positive  True  False  False        True         0.00
# 217270   Mostly Positive  True  False  False        True         3.99
# 858050     Very Positive  True  False  False        True         8.99
# 252710   Mostly Positive  True   True  False        True         6.99
# 1695480         Positive  True   True  False        True         4.99
# 1583410            Mixed  True  False  False        True         0.00
# 1079790            Mixed  True  False  False        True         9.99
# 710030     Very Positive  True  False  False        True        14.99
# 611850          Positive  True  False  False        True         3.99
# 1266100    Very Positive  True   True   True        True        11.99
# 439770   Mostly Positive  True   True   True        True         2.99
# 694770     Very Positive  True  False  False        True        19.99
# 341680          Positive  True  False  False        True         4.99
# 914290   Mostly Positive  True  False  False        True         4.99
# 1019590    Very Positive  True   True   True        True         9.99
# 690640     Very Positive  True  False  False        True        29.99
#
#                                               header_image
# app_id
# 19980    https://cdn.akamai.steamstatic.com/steam/apps/...
# 33320    https://cdn.akamai.steamstatic.com/steam/apps/...
# 621080   https://cdn.akamai.steamstatic.com/steam/apps/...
# 13530    https://cdn.akamai.steamstatic.com/steam/apps/...
# 1550840  https://cdn.akamai.steamstatic.com/steam/apps/...
# 499100   https://cdn.akamai.steamstatic.com/steam/apps/...
# 13600    https://cdn.akamai.steamstatic.com/steam/apps/...
# 545830   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1846940  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1851570  https://cdn.akamai.steamstatic.com/steam/apps/...
# 217270   https://cdn.akamai.steamstatic.com/steam/apps/...
# 858050   https://cdn.akamai.steamstatic.com/steam/apps/...
# 252710   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1695480  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1583410  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1079790  https://cdn.akamai.steamstatic.com/steam/apps/...
# 710030   https://cdn.akamai.steamstatic.com/steam/apps/...
# 611850   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1266100  https://cdn.akamai.steamstatic.com/steam/apps/...
# 439770   https://cdn.akamai.steamstatic.com/steam/apps/...
# 694770   https://cdn.akamai.steamstatic.com/steam/apps/...
# 341680   https://cdn.akamai.steamstatic.com/steam/apps/...
# 914290   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1019590  https://cdn.akamai.steamstatic.com/steam/apps/...
# 690640   https://cdn.akamai.steamstatic.com/steam/apps/...

# %% [markdown]
# ### Running the app

# %% [markdown]
# Creating code for the application.
#
# Steps performed in the code cell:
# 1. We load the dataset and crop it to top 31500 values, so it matches the size of cosine similarity matrix.
# 2. We create a form where the user can select desired game title and request the recommendations.
#     - If user did not chose the game title and requested recommendations we'll kindly ask them again to choose it.
# 3. Than we load the dataset with cosine similarities.
# 4. We obtain an id (index) of selected game title and by this id we locate a similarity vector for that game in cosine similarities dataset.
# 5. We combine similarity vector with game title ids and sort this list in descending order.
# 6. Than we pick top 25 ids from this list, excluding the first element, because it is the chosen game title itself (with similarity measure of 1).
# 7. We locate the titles with the highest similarity scores by their ids in our dataset with games.
# 8. Finally, we show selected games to the user, along with their rating, image, release date and supported platforms.

# %%
# %%writefile recommender_files/cb_recommender_by_description.py

def top_25_similar_games():
    import streamlit as st
    import pandas as pd

    # in this app we'll use dataset without encoded tags
    df = pd.read_parquet("recommender_files/data/gameset.parquet")

    # cropping the dataset
    ts = df.loc[(df["rating"] == "Overwhelmingly Positive") |
                (df["rating"] == "Very Positive") |
                (df["rating"] == "Positive") |
                (df["rating"] == "Mostly Positive") |
                (df["rating"] == "Mixed")].sort_values(by =
                                                      ["user_reviews",
                                                       "positive_ratio"],
                                                       ascending = False)

    ts = ts[["title", "date_release", "rating", "win", "mac",
             "linux", "steam_deck", "price_final", "header_image"]][:31500]

    # creating a form to select an game title
    with st.form("my_form"):

        st.title("Top-25 similar games")

        game_title = st.selectbox("Game Title:",
                        options = ts["title"].values,
                        index = None,
                        placeholder = "Start typing to search among options")
        st.write('You selected:', game_title)


        submitted = st.form_submit_button("Recommend")

        if submitted:
            # kindly ask for game title if none was provided
            if game_title == None:
                st.write("Please, consider choosing a game title")
            # proceed if game title was provided
            else:
                # loading dataset with cosine similarities
                csf = pd.read_parquet("recommender_files/cosine similarities/descriptions/cosine_similarity.parquet")
                for i in range(2,5):
                    csf = pd.concat([csf, pd.read_parquet(f"recommender_files/cosine similarities/descriptions/cosine_similarity{i}.parquet")])

                # obtaining app id of chosen game title
                game_id = ts.loc[ts["title"] == game_title].index

                # locating a similarity vector by app id
                cosine_similarity = csf.loc[game_id, "cosine_similarity"].values[0]
                # combining similarity vector with app ids and sorting the list
                cosine_similarity = list(zip(cosine_similarity, csf.index))
                cosine_similarity = sorted(cosine_similarity, reverse = True)

                # choosing app ids of top 25 games
                ids = [i[1] for i in cosine_similarity[1:26]]

                # locating games by app ids in the dataset
                table = ts.loc[ids]

                platforms = ["Windows", "MacOS", "Linux", "SteamDeck"]

                # showing top 25 games from sorted dataset
                for index in table.index:

                    supported_platforms = list(df.loc[index, ["win", "mac", "linux", "steam_deck"]])
                    supported_platforms = list(zip(platforms, supported_platforms))
                    supported_platforms = [i[0] for i in supported_platforms if i[1] == True]

                    # creating an information card for each of the games
                    with st.container():

                        st.header(table.loc[index, "title"], divider = "rainbow")

                        col1, col2 = st.columns([1, 2])

                        with col1:
                            st.image(table.loc[index, "header_image"])

                        with col2:
                            if table.loc[index, 'rating'] == "Mixed":
                                st.subheader(f"_Rating_: :orange[{table.loc[index, 'rating']}]")
                            else:
                                st.subheader(f"_Rating_: :green[{table.loc[index, 'rating']}]")
                            st.text(f"Reliase date: {table.loc[index, 'date_release']}")
                            st.text(("Supported plarforms: " + ", ".join(supported_platforms)))
                            if table.loc[index, 'price_final'] == 0.0:
                                st.text(f"Price: Free")
                            else:
                                st.text(f"Price: {table.loc[index, 'price_final']}$")

top_25_similar_games()
# Out:
# Overwriting recommender_files/cb_recommender_by_description.py

# %% [markdown]
# You can run the app by running the code in the next two cells. *(Please, be patient and wait while the first cell will finish it's execution.)*
#
# ***! This application will take ~1 minute to load the results.***

# %%
# restarting the Colab kernel to free all RAM
import os
os._exit(00)

# %%
# !pip install streamlit &> /dev/null
# !npm install localtunnel &> /dev/null

# !streamlit run recommender_files/cb_recommender_by_description.py & >/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com

# %% [markdown]
# ## Content-Based Recommender Using Title Metadata

# %%
# restarting the Colab kernel to free all RAM
import os
os._exit(00)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading Saved Dataset

# %%
mds = pd.read_parquet("recommender_files/data/gameset.parquet")

# %% [markdown]
# In this case we are going to recommend games only with positive reviews, because cosine similarity is even more computationally expensive than linear kernel, used before.

# %%
# mdts stands for metadata truncated set
mdts = mds.loc[(mds["rating"] == "Overwhelmingly Positive") |
               (mds["rating"] == "Very Positive") |
               (mds["rating"] == "Positive") |
               (mds["rating"] == "Mostly Positive")].sort_values(by =
                                                                ["user_reviews",
                                                                "positive_ratio"],
                                                                ascending = False)

mdts.head()
# Out:
#                                title date_release  \
# app_id
# 304930                      Unturned   2017-07-07
# 1281930                   tModLoader   2020-05-16
# 698780    Doki Doki Literature Club!   2017-10-06
# 319630   Life is Strange - Episode 1   2015-01-29
# 700330        SCP: Secret Laboratory   2017-12-29
#
#                                                description  \
# app_id
# 304930   You're a survivor in the zombie infested ruins...
# 1281930  Dig, Fight, and Build your way through the wor...
# 698780   The Literature Club is full of cute girls! Wil...
# 319630   Episode 1 now FREE! Life is Strange is an awar...
# 700330   Deep within the SCP Foundation during a contai...
#
#                                                       tags  \
# app_id
# 304930   [Free to Play, Survival, Zombies, Multiplayer,...
# 1281930  [Adventure, Action, Free to Play, Indie, RPG, ...
# 698780   [Psychological Horror, Visual Novel, Anime, Fr...
# 319630   [Story Rich, Choices Matter, Great Soundtrack,...
# 700330   [Free to Play, Horror, Multiplayer, First-Pers...
#
#                                                 developers  \
# app_id
# 304930                             [Smartly Dressed Games]
# 1281930                                               None
# 698780                                      [Team Salvato]
# 319630   [DONTNOD Entertainment, Feral Interactive (Mac...
# 700330                                 [Northwood Studios]
#
#                           rating  positive_ratio  user_reviews   win    mac  \
# app_id
# 304930             Very Positive              91        515016  True   True
# 1281930  Overwhelmingly Positive              97        188684  True   True
# 698780   Overwhelmingly Positive              96        184949  True   True
# 319630   Overwhelmingly Positive              96        160660  True   True
# 700330             Very Positive              91        154538  True  False
#
#          linux  steam_deck  price_final  \
# app_id
# 304930    True        True         0.00
# 1281930   True        True         0.00
# 698780   False        True         0.00
# 319630    True        True        19.99
# 700330   False        True         0.00
#
#                                               header_image
# app_id
# 304930   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1281930  https://cdn.akamai.steamstatic.com/steam/apps/...
# 698780   https://cdn.akamai.steamstatic.com/steam/apps/...
# 319630   https://cdn.akamai.steamstatic.com/steam/apps/...
# 700330   https://cdn.akamai.steamstatic.com/steam/apps/...

# %% [markdown]
# Checking if any games have missing values in "developers" column.

# %%
mdts["developers"].isna().sum()
# Out:
# 185

# %% [markdown]
# Looks like, there are 185 missing values.
#
# Living 185 potentially good games behind is not very nice, so lets find them.

# %% [markdown]
# After two hours of laborious work all missing developers were found.
#
# *party*

# %%
missing_developers = [
["TML Team"],
["(Hong Kong) GKD"],
["Prism Game Studios Ltd."],
["Gearbox Software", "Blind Squirrel Games"],
["Laser Unicorns"],
["PORTANIS"],
["Breadmen"],
["The Chronicles Of Myrtana Team"],
["UL Solutions"],
["SureAI"],
["Valve"],
["CAPCOM Co., Ltd."],
["KINODOM PRODUCTIONS"],
["empty"],
["Breadman"],
["Alan Edwardes"],
["Filip Victor", "Valve"],
["Vortal Storm"],
["Odd Time Studios", "Aperture Tag Team", "Rockhopper Studios"],
["empty"],
["SureAI"],
["Oats Studios"],
["Stridemann"],
["Source VR Mod Team"],
["FireFly Studios"],
["Croteam"],
["One More Level", "3D Realms", "Slipgate Ironworks™", "All in! Games"],
["Future Games Select, Cayle George"],
["marnamai"],
["STUDIO RADI-8"],
["Table 9 Studio"],
["empty"],
["TEAM JBMOD"],
["Caustic Creative"],
["Tripwire Interactive, Type AB"],
["Blitzkrieg Mod Team"],
["empty"],
["Galactic Cafe"],
["Bohemia Interactive"],
["SnowDropEscape development team"],
["RTK Entertainment"],
["Chuck Wilson"],
["empty"],
["Spike Chunsoft Co., Ltd."],
["Masangsoft"],
["Frere d'Arme"],
["Prism Game Studios Ltd."],
["Team ModCom"],
["Fortress Forever Development Team", "Trepid Studios"],
["Archaic Entertainment"],
["MMod Team"],
["OVERKILL - a Starbreeze Studio.", "Payday Productions"],
["Darklight Games"],
["Team Jabroni"],
["The SKSE Team"],
["Relic Entertainment", "Europe at War Development Team"],
["Troiz"],
["Wolfmap", "RTCWCoop Team", "Dark Matter Productions"],
["empty"],
["Benjamin Bryant"],
["Vect0R"],
["SureAI"],
["ichbinhamma"],
["Elseware Experience"],
["Evac Dev. Team"],
["Relic Entertainment", "The Great War 1918 Development Team"],
["KONAMI"],
["Bitl Development Studio"],
["Wevr, Inc."],
["Tripwire Interactive", "Kernow Interactive"],
["Corridor Digital", "Ubisoft Entertainment"],
["empty"],
["Rusty Lake", "The LAB"],
["Bohemia Interactive"],
["NetherRealm Studios", "Warner Bros. Interactive Entertainment"],
["EXOR Studios"],
["empty"],
["HLA team"],
["TechSmith Corporation"],
["yeo"],
["Philipp Lehner"],
["Crystice Softworks"],
["Kirill Bulavintsev"],
["Blendo Games"],
["iDragons creative studio"],
["ONEONE1"],
["Eric Schafenberg"],
["PLut"],
["Roroco Studio"],
["Telltale Games"],
["Relic Entertainment", "Modern Combat Development Team", "Black Sand Studios"],
["Reaktor"],
["Source VR Mod Team"],
["Black Chicken Studios, inc."],
["From Earth Team"],
["KINODOM PRODUCTIONS"],
["NetherRealm Studios", "Warner Bros. Interactive Entertainment"],
["Astrabit Studios"],
["Infogrames"],
["VisualArts/Key"],
["WIZNWAR", "FLARB LLC"],
["Running With Scissors"],
["YellowAfterlife"],
["JaviteSoft"],
["Edmund McMillen and Florian Himsl"],
["Volition"],
["empty"],
["Tim Bergholz - Chamfer Zone"],
["Source VR Mod Team"],
["Ubisoft Montreal"],
["Sprouting Potato"],
["KOEI TECMO GAMES CO., LTD."],
["MadLife Divertissement"],
["Telltale Games"],
["Sandstorm Productions"],
["Heath Games"],
["Warhorse Studios"],
["TashiKani"],
["Digital Paintball"],
["KLRU-TV", "Austin PBS"],
["Bethesda Game Studios"],
["Battle of Crete Development Team"],
["Infogrames"],
["Leikir Studio"],
["Microsoft Studios"],
["Fuzzy Ghost"],
["Valve"],
["Warner Bros."],
["Ignishot"],
["IDEA FACTORY", "Frontier Works"],
["Lunastellia", "Matux"],
["Nitreal", "GameHouse"],
["Gentlymad Studios"],
["Infogrames"],
["oneoreight", "Team EARTHWARS"],
["Schmidt Workshops"],
["CREATIVE ASSEMBLY"],
["Team Reliquary ltd."],
["橘喵喵"],
["Crank Goblin"],
["Lucas Pope and Keiko Ishizaka"],
["Warhorse Studios"],
["Noclip Video"],
["Valve"],
["Grab Games"],
["Subverse Productions"],
["Bohemia Interactive"],
["Matthew Bradshaw"],
["Insurgency Development Team"],
["Team Chivalry"],
["Stefan Kraus", "Timo Armbruster"],
["Valve"],
["Supergiant Games"],
["SMG Studio"],
["RO2/RS Community", "Tripwire Interactive"],
["The Game Bakers"],
["CAPCOM CO., LTD."],
["Devolver Digital"],
["Raw Fury"],
["Endless Loop Studios", "Code Monkey"],
["Cold Beam Games"],
["RO2/RS Community", "Tripwire Interactive"],
["Wargaming Group Limited"],
["Geeta Games"],
["Dr BLOC"],
["Bohemia Interactive"],
["MicroProse Software, Inc"],
["谭浩翔"],
["Double Fine Productions"],
["Atomic Wolf", "L.INC"],
["Daedalic Entertainment"],
["These Are The Good Games"],
["ChamferZone"],
["Wargaming Group Limited"],
["Adam Foster"],
["Mighty Rocket Studio"],
["The Blank Canvas", "Lobo"],
["ChamferZone"],
["empty"],
["Mixamo"],
["Yanka Prod"],
["Clouds and Blue"],
["One Hamsa"],
["NEKO WORKs"],
["Gone Coyote"]
]

# %%
missing_developers_ids = mdts.loc[mdts["developers"].isna()].index

# %% [markdown]
# Adding missing developers to the dataset.

# %%
for entry in zip(missing_developers_ids, missing_developers):
    mdts.at[entry[0], "developers"] = entry[1]

# %% [markdown]
# Dropping the columns with empty entries.

# %%
empty_developers_ids = list()
for index, value in zip(mdts["developers"].index, mdts["developers"]):
    if len(value) == 0:
        empty_developers_ids.append(index)

# %%
mdts = mdts.drop(index = empty_developers_ids)

# %% [markdown]
# ### Creating Metadata Column

# %% [markdown]
# Removing whitespaces in developer's names and in tags, so they could be recognized as one-word entries.

# %%
def preprocess_text(x):
    return [str.lower(i.replace(" ", "")) for i in x]

# %%
for feature in ["developers", "tags"]:
    mdts[feature] = mdts[feature].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x])

# %% [markdown]
# Joining values from `developers` and `tags` columns into new `metadata` column.

# %%
mdts["metadata"] = mdts.apply(lambda x: " ".join(x["developers"]) +
                                        " " +
                                        " ".join(x["tags"]), axis = 1)

# %%
mdts["metadata"][:1].values
# Out:
# array(['smartlydressedgames freetoplay survival zombies multiplayer openworld co-op crafting sandbox adventure shooter first-person post-apocalyptic lootershooter action fps singleplayer massivelymultiplayer atmospheric indie casual'],
#       dtype=object)

# %% [markdown]
# Saving dataset for further use in the application.

# %%
mdts.to_parquet("recommender_files/data/gameset_with_metadata.parquet")

# %% [markdown]
# ### Creating Document Vectors
#
# For this case we are going to use Count Vectorizer, because, unlike previously, we don't want to put more emphasis on rare cases (like developer, or very specific genre).
#
# ***! Note on cropping***
#
# The dataset is cropped to top 25500 data entries so it could fit in 12.7 GB of (free) Colab RAM.

# %%
from sklearn.feature_extraction.text import CountVectorizer

cvec = CountVectorizer(strip_accents = "unicode", stop_words = "english")

mdts = mdts["metadata"].copy()
count_matrix = cvec.fit_transform(mdts[:25500])

# %% [markdown]
# Computing cosine similarity matrix, storing it into the dataset and saving it for later use in the application.

# %%
from sklearn.metrics.pairwise import cosine_similarity

cos_sim = cosine_similarity(count_matrix)

# %%
# stands for meta cosine similarity
mcs = pd.DataFrame(list(zip(mdts[:25500].index, cos_sim)))
mcs.columns = ["app_id", "cosine_similarity"]
mcs = mcs.set_index("app_id")

# %%
# mcs[:6375].to_parquet("recommender_files/cosine similarities/meta/cos_sim.parquet")
# mcs[6375:12750].to_parquet("recommender_files/cosine similarities/meta/cos_sim2.parquet")
# mcs[12750:19125].to_parquet("recommender_files/cosine similarities/meta/cos_sim3.parquet")
# mcs[19125:].to_parquet("recommender_files/cosine similarities/meta/cos_sim4.parquet")

# %% [markdown]
# ### Checking results
#
# (*If kernel shuts down just run the cell one more time.*)

# %%
# enter app title here (in case you want to try yourself)
game_title = "Prince of Persia: Warrior Within™"

import pandas as pd
mds = pd.read_parquet("recommender_files/data/gameset.parquet")

mcs = pd.read_parquet("recommender_files/cosine similarities/meta/cos_sim.parquet")
for i in range(2,5):
    mcs = pd.concat([mcs, pd.read_parquet(f"recommender_files/cosine similarities/meta/cos_sim{i}.parquet")])


mdts = mds.loc[(mds["rating"] == "Overwhelmingly Positive") |
               (mds["rating"] == "Very Positive") |
               (mds["rating"] == "Positive") |
               (mds["rating"] == "Mostly Positive")].sort_values(by =
                                                                ["user_reviews",
                                                                 "positive_ratio"],
                                                                 ascending = False)

mdts = mdts[["title", "date_release", "rating", "win", "mac",
             "linux", "steam_deck", "price_final", "header_image"]][:25500]


game_id = mdts.loc[mdts["title"] == game_title].index

cosine_similarity = mcs.loc[game_id, "cosine_similarity"].values[0]
cosine_similarity = list(zip(cosine_similarity, mcs.index))
cosine_similarity = sorted(cosine_similarity, reverse = True)

ids = [i[1] for i in cosine_similarity[1:26]]

table = mdts.loc[ids]

display(table.head(25))

del([mds, mcs, mdts, game_id, cosine_similarity, ids, table])
# Out:
#                                                    title date_release  \
# app_id
# 13600               Prince of Persia®: The Sands of Time   2008-11-21
# 13530                 Prince of Persia: The Two Thrones™   2008-11-21
# 19980                                  Prince of Persia®   2008-12-10
# 224920                       Legacy of Kain: Soul Reaver   1999-09-08
# 388410                Darksiders II Deathinitive Edition   2015-11-05
# 606280                                    Darksiders III   2018-11-27
# 224300                          Legacy of Kain: Defiance   2012-12-06
# 7000                                 Tomb Raider: Legend   2007-03-29
# 245280   ENSLAVED™: Odyssey to the West™ Premium Edition   2013-10-24
# 355790                          Styx: Shards of Darkness   2017-03-14
# 242640                           Styx: Master of Shadows   2014-10-07
# 40390                               Risen 2: Dark Waters   2012-04-26
# 260190   Marc Eckō's Getting Up: Contents Under Pressure   2013-12-13
# 493200                                              RiME   2017-05-26
# 241930                  Middle-earth™: Shadow of Mordor™   2014-09-30
# 404680                                               Hob   2017-09-26
# 253980                                           Enclave   2013-10-04
# 12710                            Overlord™: Raising Hell   2008-02-28
# 8140                             Tomb Raider: Underworld   2008-11-21
# 462780                    Darksiders Warmastered Edition   2016-11-29
# 220440                                DmC: Devil May Cry   2013-01-24
# 1132980              There Is No Light: Enhanced Edition   2022-09-19
# 33230                                 Assassin's Creed 2   2010-03-09
# 15130                              Beyond Good and Evil™   2008-05-13
# 15100          Assassin's Creed™: Director's Cut Edition   2008-04-09
#
#                   rating   win    mac  linux  steam_deck  price_final  \
# app_id
# 13600      Very Positive  True  False  False        True         9.99
# 13530    Mostly Positive  True  False  False        True         9.99
# 19980    Mostly Positive  True  False  False        True         9.99
# 224920   Mostly Positive  True  False  False        True         0.00
# 388410   Mostly Positive  True  False  False        True        29.99
# 606280   Mostly Positive  True  False  False        True        39.99
# 224300     Very Positive  True  False  False        True         6.99
# 7000       Very Positive  True  False  False        True         6.99
# 245280     Very Positive  True  False  False        True        19.99
# 355790     Very Positive  True  False  False        True         3.99
# 242640     Very Positive  True  False  False        True         1.99
# 40390      Very Positive  True  False  False        True         9.99
# 260190     Very Positive  True  False  False        True        14.99
# 493200     Very Positive  True  False  False        True        29.99
# 241930     Very Positive  True  False  False        True        19.99
# 404680     Very Positive  True  False  False        True         4.99
# 253980   Mostly Positive  True   True   True        True         4.99
# 12710      Very Positive  True  False  False        True         9.99
# 8140     Mostly Positive  True  False  False        True         8.99
# 462780     Very Positive  True  False  False        True        19.99
# 220440     Very Positive  True  False  False        True        29.99
# 1132980  Mostly Positive  True  False  False        True        24.99
# 33230      Very Positive  True  False  False        True        19.99
# 15130      Very Positive  True  False  False        True         9.99
# 15100      Very Positive  True  False  False        True        19.99
#
#                                               header_image
# app_id
# 13600    https://cdn.akamai.steamstatic.com/steam/apps/...
# 13530    https://cdn.akamai.steamstatic.com/steam/apps/...
# 19980    https://cdn.akamai.steamstatic.com/steam/apps/...
# 224920   https://cdn.akamai.steamstatic.com/steam/apps/...
# 388410   https://cdn.akamai.steamstatic.com/steam/apps/...
# 606280   https://cdn.akamai.steamstatic.com/steam/apps/...
# 224300   https://cdn.akamai.steamstatic.com/steam/apps/...
# 7000     https://cdn.akamai.steamstatic.com/steam/apps/...
# 245280   https://cdn.akamai.steamstatic.com/steam/apps/...
# 355790   https://cdn.akamai.steamstatic.com/steam/apps/...
# 242640   https://cdn.akamai.steamstatic.com/steam/apps/...
# 40390    https://cdn.akamai.steamstatic.com/steam/apps/...
# 260190   https://cdn.akamai.steamstatic.com/steam/apps/...
# 493200   https://cdn.akamai.steamstatic.com/steam/apps/...
# 241930   https://cdn.akamai.steamstatic.com/steam/apps/...
# 404680   https://cdn.akamai.steamstatic.com/steam/apps/...
# 253980   https://cdn.akamai.steamstatic.com/steam/apps/...
# 12710    https://cdn.akamai.steamstatic.com/steam/apps/...
# 8140     https://cdn.akamai.steamstatic.com/steam/apps/...
# 462780   https://cdn.akamai.steamstatic.com/steam/apps/...
# 220440   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1132980  https://cdn.akamai.steamstatic.com/steam/apps/...
# 33230    https://cdn.akamai.steamstatic.com/steam/apps/...
# 15130    https://cdn.akamai.steamstatic.com/steam/apps/...
# 15100    https://cdn.akamai.steamstatic.com/steam/apps/...

# %% [markdown]
# ### Running the app

# %% [markdown]
# This application works by the same scenario as previous one.
#
# It differs from previous only in size ot the dataset, absence of reviews with "Mixed" rating and different values in similarity vectors.

# %%
# %%writefile recommender_files/cb_recommender_by_metadata.py

def top_25_similar_games_by_meta():
    import streamlit as st
    import pandas as pd

    # in this app we'll use pre-saved dataset with metadata
    mds = pd.read_parquet("recommender_files/data/gameset_with_metadata.parquet")

    # cropping the dataset
    mdts = mds.loc[(mds["rating"] == "Overwhelmingly Positive") |
                   (mds["rating"] == "Very Positive") |
                   (mds["rating"] == "Positive") |
                   (mds["rating"] == "Mostly Positive")].sort_values(by =
                                                                    ["user_reviews",
                                                                     "positive_ratio"],
                                                                     ascending = False)

    mdts = mdts[["title", "date_release", "rating", "win", "mac",
             "linux", "steam_deck", "price_final", "header_image"]][:25500]

    # creating a form to select an game title
    with st.form("my_form"):

        st.title("Top-25 similar games (by metadata)")

        game_title = st.selectbox("Game Title:",
                        options = mdts["title"].values,
                        index = None,
                        placeholder = "Start typing to search among options")
        st.write('You selected:', game_title)


        submitted = st.form_submit_button("Recommend")

        if submitted:
            # kindly ask for game title if none was provided
            if game_title == None:
                st.write("Please, consider choosing a game title")
            # proceed if game title was provided
            else:
                # loading dataset with cosine similarities
                mcs = pd.read_parquet("recommender_files/cosine similarities/meta/cos_sim.parquet")
                for i in range(2,5):
                    mcs = pd.concat([mcs, pd.read_parquet(f"recommender_files/cosine similarities/meta/cos_sim{i}.parquet")])

                # obtaining app id of chosen game title
                game_id = mdts.loc[mdts["title"] == game_title].index

                # locating a similarity vector by app id
                cosine_similarity = mcs.loc[game_id, "cosine_similarity"].values[0]
                # combining similarity vector with app ids and sorting the list
                cosine_similarity = list(zip(cosine_similarity, mcs.index))
                cosine_similarity = sorted(cosine_similarity, reverse = True)

                # choosing app ids of top 25 games
                ids = [i[1] for i in cosine_similarity[1:26]]

                # locating games by app ids in the dataset
                table = mdts.loc[ids]

                platforms = ["Windows", "MacOS", "Linux", "SteamDeck"]

                # showing top 25 games from sorted dataset
                for index in table.index:

                    supported_platforms = list(mdts.loc[index, ["win", "mac", "linux", "steam_deck"]])
                    supported_platforms = list(zip(platforms, supported_platforms))
                    supported_platforms = [i[0] for i in supported_platforms if i[1] == True]

                    # creating an information card for each of the games
                    with st.container():

                        st.header(table.loc[index, "title"], divider = "rainbow")

                        col1, col2 = st.columns([1, 2])

                        with col1:
                            st.image(table.loc[index, "header_image"])

                        with col2:
                            if table.loc[index, 'rating'] == "Mixed":
                                st.subheader(f"_Rating_: :orange[{table.loc[index, 'rating']}]")
                            else:
                                st.subheader(f"_Rating_: :green[{table.loc[index, 'rating']}]")
                            st.text(f"Reliase date: {table.loc[index, 'date_release']}")
                            st.text(("Supported plarforms: " + ", ".join(supported_platforms)))
                            if table.loc[index, 'price_final'] == 0.0:
                                st.text(f"Price: Free")
                            else:
                                st.text(f"Price: {table.loc[index, 'price_final']}$")

top_25_similar_games_by_meta()

# %% [markdown]
# You can run the app by running the code in the next two cells.
#
# ***! This application will take ~30 seconds to load the results.***

# %%
# restarting the Colab kernel to free all RAM
import os
os._exit(00)

# %%
# !pip install streamlit &> /dev/null
# !npm install localtunnel &> /dev/null

# !streamlit run recommender_files/cb_recommender_by_metadata.py & >/content/logs.txt & npx localtunnel --port 8501 & curl ipv4.icanhazip.com

# %% [markdown]
# # And we are done
# ## Thanks for staying till the end
